# %% [markdown]
# # Backbone results

# %% [markdown]
# ## Import libraries

# %%
import json
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# /tmp/ipykernel_62687/2099343663.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Construct table

# %%
output = []
for dataset in ["CASP14", "CASP13"]:
    dataset_path = Path(dataset)
    for template_path in dataset_path.glob("*.fasta"):
        template = template_path.stem
        methods = [
            "FLAT_1",
            "FLAT_1_AF",
            "FLAT_1_RANK",
            "FLAT_1_OF_SS_1",
            "FLAT_1_OF_EMPTY_1",
            "FLAT_1_OF_SS_2",
            "FLAT_1_OF_EMPTY_2",
            "FLAT_2",
            "FLAT_2_AF",
            "FLAT_2_RANK",
            "FLAT_2_OF_SS_1",
            "FLAT_2_OF_EMPTY_1",
            "FLAT_2_OF_SS_2",
            "FLAT_2_OF_EMPTY_2",
            "NOISE",
            "NOISE_AF",
            "NOISE_RANK",
            "NOISE_OF_SS_1",
            "NOISE_OF_EMPTY_1",
            "NOISE_OF_SS_2",
            "NOISE_OF_EMPTY_2",
            "full",
            "single",
        ]
        methods1 = [
            [
                f"RF_{noise}",
                f"RF_{noise}_FASPR",
                f"RF_{noise}_ATTN",
                f"RF_{noise}_FASPR_AF",
                f"RF_{noise}_ATTN_AF",
                f"RF_{noise}_RANK",
                f"RF_{noise}_OF_SS_1",
                f"RF_{noise}_OF_EMPTY_1",
                f"RF_{noise}_OF_SS_2",
                f"RF_{noise}_OF_EMPTY_2",
            ]
            for noise in ["1", "5", "10"]
        ]
        methods.extend(sum(methods1, []))
        for method in methods:
            if Path(f"{dataset_path}_{method}/{template}/ost_scores.json").exists():
                scores_path = Path(
                    f"{dataset_path}_{method}/{template}/ost_scores.json"
                )
            elif Path(f"{dataset_path}_{method}/{template}/scores.json").exists():
                scores_path = Path(f"{dataset_path}_{method}/{template}/scores.json")
            else:
                continue
            with open(scores_path, "r") as scores_file:
                curr_score = json.load(scores_file)
            if not ("tm_score" in curr_score):
                continue
            curr_output = {
                "dataset": dataset,
                "template": template,
                "method": method,
                "tm_score": curr_score["tm_score"],
                "rmsd": curr_score["rmsd"],
                "lddt": curr_score["lddt"],
            }
            output.append(curr_output)
df = pd.DataFrame(output)
df
# Out:
# /tmp/ipykernel_3978491/362089897.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#      dataset template             method  tm_score       rmsd      lddt
# 0     CASP14    T1079             FLAT_1  0.187089  21.975626  0.226514
# 1     CASP14    T1079          FLAT_1_AF  0.140322  44.428783  0.089533
# 2     CASP14    T1079     FLAT_1_OF_SS_1  0.225171  26.615742  0.179368
# 3     CASP14    T1079  FLAT_1_OF_EMPTY_1  0.195786  30.257912  0.168983
# 4     CASP14    T1079     FLAT_1_OF_SS_2  0.224974  31.941208  0.186893
# ...      ...      ...                ...       ...        ...       ...
# 6140  CASP13    T1003      RF_10_ATTN_AF  0.935782   2.069904  0.699308
# 6141  CASP13    T1003      RF_10_OF_SS_1  0.937669   2.215363  0.752735
# 6142  CASP13    T1003   RF_10_OF_EMPTY_1  0.943015   2.032181  0.759028
# 6143  CASP13    T1003      RF_10_OF_SS_2  0.944457   1.967986  0.775445
# 6144  CASP13    T1003   RF_10_OF_EMPTY_2  0.958093   1.687144  0.783494
#
# [6145 rows x 6 columns]

# %% [markdown]
# ## Check if all setups are here
# T0954 missing

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
df[df.template != "T0954"].groupby(["method", "dataset"])["template"].agg("count")
# Out:
# method             dataset
# FLAT_1             CASP13     77
#                    CASP14     62
# FLAT_1_AF          CASP13     77
#                    CASP14     62
# FLAT_1_OF_EMPTY_1  CASP13     77
#                    CASP14     62
# FLAT_1_OF_EMPTY_2  CASP13     77
#                    CASP14     62
# FLAT_1_OF_SS_1     CASP13     77
#                    CASP14     62
# FLAT_1_OF_SS_2     CASP13     77
#                    CASP14     62
# FLAT_2             CASP13     77
#                    CASP14     62
# FLAT_2_AF          CASP13     77
#                    CASP14     62
# FLAT_2_OF_EMPTY_1  CASP13     77
#                    CASP14     62
# FLAT_2_OF_EMPTY_2  CASP13     77
#                    CASP14     62
# FLAT_2_OF_SS_1     CASP13     77
#                    CASP14     62
# FLAT_2_OF_SS_2     CASP13     77
#                    CASP14     62
# NOISE              CASP13     77
#                    CASP14     62
# NOISE_AF           CASP13     77
#                    CASP14     62
# NOISE_OF_EMPTY_1   CASP13     77
#                    CASP14     62
# NOISE_OF_EMPTY_2   CASP13     77
#                    CASP14     62
# NOISE_OF_SS_1      CASP13     77
#                    CASP14     62
# NOISE_OF_SS_2      CASP13     77
#                    CASP14     62
# RF_10_ATTN         CASP13     77
#                    CASP14     62
# RF_10_ATTN_AF      CASP13     77
#                    CASP14     62
# RF_10_FASPR        CASP13     77
#                    CASP14     62
# RF_10_FASPR_AF     CASP13     77
#                    CASP14     62
# RF_10_OF_EMPTY_1   CASP13     77
#                    CASP14     62
# RF_10_OF_EMPTY_2   CASP13     77
#                    CASP14     62
# RF_10_OF_SS_1      CASP13     77
#                    CASP14     62
# RF_10_OF_SS_2      CASP13     77
#                    CASP14     62
# RF_1_ATTN          CASP13     77
#                    CASP14     62
# RF_1_ATTN_AF       CASP13     77
#                    CASP14     62
# RF_1_FASPR         CASP13     77
#                    CASP14     62
# RF_1_FASPR_AF      CASP13     77
#                    CASP14     62
# RF_1_OF_EMPTY_1    CASP13     77
#                    CASP14     62
# RF_1_OF_EMPTY_2    CASP13     77
#                    CASP14     62
# RF_1_OF_SS_1       CASP13     77
#                    CASP14     62
# RF_1_OF_SS_2       CASP13     77
#                    CASP14     62
# RF_5_ATTN          CASP13     77
#                    CASP14     62
# RF_5_ATTN_AF       CASP13     77
#                    CASP14     62
# RF_5_FASPR         CASP13     77
#                    CASP14     62
# RF_5_FASPR_AF      CASP13     77
#                    CASP14     62
# RF_5_OF_EMPTY_1    CASP13     77
#                    CASP14     62
# RF_5_OF_EMPTY_2    CASP13     77
#                    CASP14     62
# RF_5_OF_SS_1       CASP13     77
#                    CASP14     62
# RF_5_OF_SS_2       CASP13     77
#                    CASP14     62
# full               CASP13     77
#                    CASP14     62
# single             CASP13     77
#                    CASP14     62
# Name: template, dtype: int64

# %% [markdown]
# ## Table constants

# %%
# some variable names need to be changed
columns = [
    "TM-score $\\uparrow$",
    "lDDT $\\uparrow$",
    "$\\alpha$-RMSD ($\\AA$) $\\downarrow$",
]
measure_dict = {
    "lddt": "lDDT $\\uparrow$",
    "tm_score": "TM-score $\\uparrow$",
    "af_pLDDT_mean": "pLDDT $\\uparrow$",
    "rmsd": "$\\alpha$-RMSD ($\\AA$) $\\downarrow$",
    "method": "Method",
    "dataset": "Dataset",
}
method_dict = {
    "full": "MSA",
    "single": "Single",
    "NOISE": "Gaussian",
    "NOISE_AF": "Gaussian (AF)",
    "NOISE_OF_SS": "Gaussian (Rank Single)",
    "NOISE_OF_EMPTY": "Gaussian (Rank Empty)",
    "FLAT_1": "1 PC",
    "FLAT_1_AF": "1 PC (AF)",
    "FLAT_1_OF_SS": "1 PC (Rank Single)",
    "FLAT_1_OF_EMPTY": "1 PC (Rank Empty)",
    "FLAT_2": "2 PC",
    "FLAT_2_AF": "2 PC (AF)",
    "FLAT_2_OF_SS": "2 PC (Rank Single)",
    "FLAT_2_OF_EMPTY": "2 PC (Rank Empty)",
    "RF_1_ATTN": "1 RFDiff (AP)",
    "RF_1_ATTN_AF": "1 RFDiff (AP AF)",
    "RF_1_FASPR": "1 RFDiff (FASPR)",
    "RF_1_FASPR_AF": "1 RFDiff (FASPR AF)",
    "RF_1_OF_SS": "1 RFDiff (Rank Single)",
    "RF_1_OF_EMPTY": "1 RFDiff (Rank Empty)",
    "RF_5_ATTN": "5 RFDiff (AP)",
    "RF_5_ATTN_AF": "5 RFDiff (AP AF)",
    "RF_5_FASPR": "5 RFDiff (FASPR)",
    "RF_5_FASPR_AF": "5 RFDiff (FASPR AF)",
    "RF_5_OF_SS": "5 RFDiff (Rank Single)",
    "RF_5_OF_EMPTY": "5 RFDiff (Rank Empty)",
    "RF_10_ATTN": "10 RFDiff (AP)",
    "RF_10_ATTN_AF": "10 RFDiff (AP AF)",
    "RF_10_FASPR_AF": "10 RFDiff (FASPR AF)",
    "RF_10_FASPR": "10 RFDiff (FASPR)",
    "RF_10_OF_SS": "10 RFDiff (Rank Single)",
    "RF_10_OF_EMPTY": "10 RFDiff (Rank Empty)",
}

# %% [markdown]
# ## Prepare DataFrame

# %%
df = df[df.template != "T0954"]
df["type"] = df["method"].apply(
    lambda x: x[:-2] if x[-1].isnumeric() and len(x) > 6 else x
)
df["Method"] = df.rename(measure_dict, axis=1)["type"].replace(method_dict)
grouped = (
    df.drop("method", axis=1)
    .rename(measure_dict, axis=1)
    .sort_values("TM-score $\\uparrow$", ascending=False)
    .groupby(["Method", "template"])
    .agg("first")
    .groupby(["Method", "Dataset"])[columns]
    .agg("mean")
    .sort_values(["Method", "Dataset"])
)
grouped_std = (
    df.drop("method", axis=1)
    .rename(measure_dict, axis=1)
    .sort_values("TM-score $\\uparrow$", ascending=False)
    .groupby(["Method", "template"])
    .agg("first")
    .groupby(["Method", "Dataset"])[columns]
    .agg("std")
    .sort_values(["Method", "Dataset"])
)
for column in columns:
    grouped_std[f"{column}"] = (
        grouped[column].apply(lambda x: f"{x:.3f}")
        + "$\\pm$"
        + grouped_std[column].apply(lambda x: f"{x:.3f}")
    )
grouped_std
# Out:
# /tmp/ipykernel_3978491/2349091617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["type"]=df["method"].apply(lambda x: x[:-2] if x[-1].isnumeric() and len(x)>6 else x )
# /tmp/ipykernel_3978491/2349091617.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Method"] = df.rename(measure_dict, axis=1)["type"].replace(method_dict)
#                                 TM-score $\uparrow$  lDDT $\uparrow$  \
# Method                  Dataset
# 1 PC                    CASP13      0.215$\pm$0.036  0.238$\pm$0.035
#                         CASP14      0.228$\pm$0.053  0.245$\pm$0.036
# 1 PC (AF)               CASP13      0.458$\pm$0.202  0.392$\pm$0.184
#                         CASP14      0.443$\pm$0.213  0.394$\pm$0.204
# 1 PC (Rank Empty)       CASP13      0.402$\pm$0.160  0.352$\pm$0.141
#                         CASP14      0.398$\pm$0.172  0.357$\pm$0.156
# 1 PC (Rank Single)      CASP13      0.402$\pm$0.150  0.358$\pm$0.134
#                         CASP14      0.412$\pm$0.170  0.368$\pm$0.163
# 1 RFDiff (AP AF)        CASP13      0.961$\pm$0.072  0.855$\pm$0.087
#                         CASP14      0.967$\pm$0.028  0.853$\pm$0.044
# 1 RFDiff (AP)           CASP13      0.970$\pm$0.037  0.836$\pm$0.028
#                         CASP14      0.974$\pm$0.013  0.827$\pm$0.028
# 1 RFDiff (FASPR AF)     CASP13      0.959$\pm$0.074  0.844$\pm$0.085
#                         CASP14      0.968$\pm$0.027  0.842$\pm$0.043
# 1 RFDiff (FASPR)        CASP13      0.970$\pm$0.037  0.810$\pm$0.028
#                         CASP14      0.974$\pm$0.013  0.804$\pm$0.026
# 1 RFDiff (Rank Empty)   CASP13      0.883$\pm$0.128  0.809$\pm$0.063
#                         CASP14      0.881$\pm$0.095  0.785$\pm$0.084
# 1 RFDiff (Rank Single)  CASP13      0.845$\pm$0.162  0.773$\pm$0.089
#                         CASP14      0.853$\pm$0.107  0.754$\pm$0.087
# 10 RFDiff (AP AF)       CASP13      0.879$\pm$0.092  0.721$\pm$0.089
#                         CASP14      0.889$\pm$0.050  0.728$\pm$0.059
# 10 RFDiff (AP)          CASP13      0.867$\pm$0.072  0.685$\pm$0.048
#                         CASP14      0.873$\pm$0.052  0.684$\pm$0.048
# 10 RFDiff (FASPR AF)    CASP13      0.874$\pm$0.092  0.709$\pm$0.088
#                         CASP14      0.884$\pm$0.053  0.715$\pm$0.059
# 10 RFDiff (FASPR)       CASP13      0.867$\pm$0.072  0.669$\pm$0.047
#                         CASP14      0.873$\pm$0.052  0.670$\pm$0.046
# 10 RFDiff (Rank Empty)  CASP13      0.854$\pm$0.128  0.764$\pm$0.077
#                         CASP14      0.844$\pm$0.099  0.742$\pm$0.089
# 10 RFDiff (Rank Single) CASP13      0.818$\pm$0.158  0.733$\pm$0.094
#                         CASP14      0.817$\pm$0.109  0.712$\pm$0.095
# 2 PC                    CASP13      0.464$\pm$0.077  0.535$\pm$0.084
#                         CASP14      0.487$\pm$0.075  0.534$\pm$0.090
# 2 PC (AF)               CASP13      0.838$\pm$0.212  0.792$\pm$0.166
#                         CASP14      0.862$\pm$0.149  0.793$\pm$0.124
# 2 PC (Rank Empty)       CASP13      0.626$\pm$0.235  0.558$\pm$0.190
#                         CASP14      0.618$\pm$0.211  0.536$\pm$0.185
# 2 PC (Rank Single)      CASP13      0.596$\pm$0.227  0.531$\pm$0.183
#                         CASP14      0.575$\pm$0.201  0.499$\pm$0.179
# 5 RFDiff (AP AF)        CASP13      0.922$\pm$0.085  0.781$\pm$0.084
#                         CASP14      0.935$\pm$0.036  0.785$\pm$0.048
# 5 RFDiff (AP)           CASP13      0.918$\pm$0.063  0.745$\pm$0.036
#                         CASP14      0.927$\pm$0.032  0.742$\pm$0.037
# 5 RFDiff (FASPR AF)     CASP13      0.919$\pm$0.089  0.768$\pm$0.083
#                         CASP14      0.933$\pm$0.036  0.772$\pm$0.049
# 5 RFDiff (FASPR)        CASP13      0.918$\pm$0.063  0.725$\pm$0.037
#                         CASP14      0.927$\pm$0.032  0.723$\pm$0.035
# 5 RFDiff (Rank Empty)   CASP13      0.873$\pm$0.125  0.788$\pm$0.066
#                         CASP14      0.868$\pm$0.091  0.767$\pm$0.078
# 5 RFDiff (Rank Single)  CASP13      0.832$\pm$0.164  0.749$\pm$0.095
#                         CASP14      0.842$\pm$0.102  0.743$\pm$0.082
# Gaussian                CASP13      0.900$\pm$0.053  0.659$\pm$0.003
#                         CASP14      0.896$\pm$0.052  0.659$\pm$0.004
# Gaussian (AF)           CASP13      0.935$\pm$0.075  0.839$\pm$0.054
#                         CASP14      0.922$\pm$0.062  0.817$\pm$0.070
# Gaussian (Rank Empty)   CASP13      0.708$\pm$0.234  0.627$\pm$0.194
#                         CASP14      0.717$\pm$0.214  0.621$\pm$0.186
# Gaussian (Rank Single)  CASP13      0.682$\pm$0.233  0.611$\pm$0.185
#                         CASP14      0.686$\pm$0.207  0.594$\pm$0.179
# MSA                     CASP13      0.858$\pm$0.162  0.833$\pm$0.095
#                         CASP14      0.840$\pm$0.147  0.791$\pm$0.116
# Single                  CASP13      0.370$\pm$0.144  0.335$\pm$0.127
#                         CASP14      0.366$\pm$0.168  0.336$\pm$0.152
#
#                                 $\alpha$-RMSD ($\AA$) $\downarrow$
# Method                  Dataset
# 1 PC                    CASP13                    14.756$\pm$8.037
#                         CASP14                    13.787$\pm$5.669
# 1 PC (AF)               CASP13                   18.466$\pm$13.492
#                         CASP14                   18.000$\pm$12.469
# 1 PC (Rank Empty)       CASP13                   19.566$\pm$11.392
#                         CASP14                   18.756$\pm$10.241
# 1 PC (Rank Single)      CASP13                   19.131$\pm$10.953
#                         CASP14                   18.504$\pm$10.069
# 1 RFDiff (AP AF)        CASP13                     1.414$\pm$2.548
#                         CASP14                     1.026$\pm$0.543
# 1 RFDiff (AP)           CASP13                     0.955$\pm$0.804
#                         CASP14                     0.851$\pm$0.268
# 1 RFDiff (FASPR AF)     CASP13                     1.418$\pm$2.510
#                         CASP14                     1.007$\pm$0.575
# 1 RFDiff (FASPR)        CASP13                     0.955$\pm$0.804
#                         CASP14                     0.851$\pm$0.268
# 1 RFDiff (Rank Empty)   CASP13                     4.668$\pm$9.710
#                         CASP14                     3.213$\pm$3.579
# 1 RFDiff (Rank Single)  CASP13                    5.754$\pm$10.510
#                         CASP14                     4.066$\pm$4.322
# 10 RFDiff (AP AF)       CASP13                     2.667$\pm$2.473
#                         CASP14                     2.109$\pm$0.658
# 10 RFDiff (AP)          CASP13                     2.501$\pm$1.683
#                         CASP14                     2.191$\pm$0.554
# 10 RFDiff (FASPR AF)    CASP13                     2.806$\pm$2.978
#                         CASP14                     2.166$\pm$0.689
# 10 RFDiff (FASPR)       CASP13                     2.501$\pm$1.683
#                         CASP14                     2.191$\pm$0.554
# 10 RFDiff (Rank Empty)  CASP13                    5.421$\pm$10.890
#                         CASP14                     3.597$\pm$2.951
# 10 RFDiff (Rank Single) CASP13                    6.250$\pm$11.003
#                         CASP14                     4.801$\pm$4.616
# 2 PC                    CASP13                     9.884$\pm$6.939
#                         CASP14                     8.786$\pm$3.749
# 2 PC (AF)               CASP13                    5.715$\pm$11.525
#                         CASP14                     3.779$\pm$5.227
# 2 PC (Rank Empty)       CASP13                   12.417$\pm$12.380
#                         CASP14                    10.445$\pm$7.978
# 2 PC (Rank Single)      CASP13                   13.423$\pm$12.195
#                         CASP14                    11.568$\pm$7.817
# 5 RFDiff (AP AF)        CASP13                     2.059$\pm$2.511
#                         CASP14                     1.529$\pm$0.665
# 5 RFDiff (AP)           CASP13                     1.826$\pm$1.684
#                         CASP14                     1.524$\pm$0.452
# 5 RFDiff (FASPR AF)     CASP13                     2.561$\pm$5.798
#                         CASP14                     1.536$\pm$0.682
# 5 RFDiff (FASPR)        CASP13                     1.826$\pm$1.684
#                         CASP14                     1.524$\pm$0.452
# 5 RFDiff (Rank Empty)   CASP13                    5.211$\pm$11.156
#                         CASP14                     3.192$\pm$2.870
# 5 RFDiff (Rank Single)  CASP13                    6.035$\pm$10.648
#                         CASP14                     4.080$\pm$4.178
# Gaussian                CASP13                     1.710$\pm$0.055
#                         CASP14                     1.712$\pm$0.058
# Gaussian (AF)           CASP13                     2.235$\pm$4.849
#                         CASP14                     1.994$\pm$1.454
# Gaussian (Rank Empty)   CASP13                   10.159$\pm$12.098
#                         CASP14                     8.879$\pm$9.597
# Gaussian (Rank Single)  CASP13                   10.457$\pm$11.728
#                         CASP14                     9.344$\pm$8.205
# MSA                     CASP13                     4.627$\pm$5.258
#                         CASP14                     4.841$\pm$5.207
# Single                  CASP13                   20.434$\pm$11.086
#                         CASP14                    19.620$\pm$9.652

# %% [markdown]
# ## Make table

# %%
selected_rows = list(method_dict.values())
grouped_std.loc[selected_rows].to_latex(escape=False, bold_rows=True)
# Out:
# '\\begin{tabular}{lllll}\n\\toprule\n &  & TM-score $\\uparrow$ & lDDT $\\uparrow$ & $\\alpha$-RMSD ($\\AA$) $\\downarrow$ \\\\\nMethod & Dataset &  &  &  \\\\\n\\midrule\n\\multirow[t]{2}{*}{\\textbf{MSA}} & \\textbf{CASP13} & 0.858$\\pm$0.162 & 0.833$\\pm$0.095 & 4.627$\\pm$5.258 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.840$\\pm$0.147 & 0.791$\\pm$0.116 & 4.841$\\pm$5.207 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{Single}} & \\textbf{CASP13} & 0.370$\\pm$0.144 & 0.335$\\pm$0.127 & 20.434$\\pm$11.086 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.366$\\pm$0.168 & 0.336$\\pm$0.152 & 19.620$\\pm$9.652 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{Gaussian}} & \\textbf{CASP13} & 0.900$\\pm$0.053 & 0.659$\\pm$0.003 & 1.710$\\pm$0.055 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.896$\\pm$0.052 & 0.659$\\pm$0.004 & 1.712$\\pm$0.058 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{Gaussian (AF)}} & \\textbf{CASP13} & 0.935$\\pm$0.075 & 0.839$\\pm$0.054 & 2.235$\\pm$4.849 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.922$\\pm$0.062 & 0.817$\\pm$0.070 & 1.994$\\pm$1.454 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{Gaussian (Rank Single)}} & \\textbf{CASP13} & 0.682$\\pm$0.233 & 0.611$\\pm$0.185 & 10.457$\\pm$11.728 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.686$\\pm$0.207 & 0.594$\\pm$0.179 & 9.344$\\pm$8.205 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{Gaussian (Rank Empty)}} & \\textbf{CASP13} & 0.708$\\pm$0.234 & 0.627$\\pm$0.194 & 10.159$\\pm$12.098 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.717$\\pm$0.214 & 0.621$\\pm$0.186 & 8.879$\\pm$9.597 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{1 PC}} & \\textbf{CASP13} & 0.215$\\pm$0.036 & 0.238$\\pm$0.035 & 14.756$\\pm$8.037 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.228$\\pm$0.053 & 0.245$\\pm$0.036 & 13.787$\\pm$5.669 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{1 PC (AF)}} & \\textbf{CASP13} & 0.458$\\pm$0.202 & 0.392$\\pm$0.184 & 18.466$\\pm$13.492 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.443$\\pm$0.213 & 0.394$\\pm$0.204 & 18.000$\\pm$12.469 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{1 PC (Rank Single)}} & \\textbf{CASP13} & 0.402$\\pm$0.150 & 0.358$\\pm$0.134 & 19.131$\\pm$10.953 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.412$\\pm$0.170 & 0.368$\\pm$0.163 & 18.504$\\pm$10.069 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{1 PC (Rank Empty)}} & \\textbf{CASP13} & 0.402$\\pm$0.160 & 0.352$\\pm$0.141 & 19.566$\\pm$11.392 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.398$\\pm$0.172 & 0.357$\\pm$0.156 & 18.756$\\pm$10.241 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{2 PC}} & \\textbf{CASP13} & 0.464$\\pm$0.077 & 0.535$\\pm$0.084 & 9.884$\\pm$6.939 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.487$\\pm$0.075 & 0.534$\\pm$0.090 & 8.786$\\pm$3.749 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{2 PC (AF)}} & \\textbf{CASP13} & 0.838$\\pm$0.212 & 0.792$\\pm$0.166 & 5.715$\\pm$11.525 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.862$\\pm$0.149 & 0.793$\\pm$0.124 & 3.779$\\pm$5.227 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{2 PC (Rank Single)}} & \\textbf{CASP13} & 0.596$\\pm$0.227 & 0.531$\\pm$0.183 & 13.423$\\pm$12.195 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.575$\\pm$0.201 & 0.499$\\pm$0.179 & 11.568$\\pm$7.817 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{2 PC (Rank Empty)}} & \\textbf{CASP13} & 0.626$\\pm$0.235 & 0.558$\\pm$0.190 & 12.417$\\pm$12.380 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.618$\\pm$0.211 & 0.536$\\pm$0.185 & 10.445$\\pm$7.978 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{1 RFDiff (AP)}} & \\textbf{CASP13} & 0.970$\\pm$0.037 & 0.836$\\pm$0.028 & 0.955$\\pm$0.804 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.974$\\pm$0.013 & 0.827$\\pm$0.028 & 0.851$\\pm$0.268 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{1 RFDiff (AP AF)}} & \\textbf{CASP13} & 0.961$\\pm$0.072 & 0.855$\\pm$0.087 & 1.414$\\pm$2.548 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.967$\\pm$0.028 & 0.853$\\pm$0.044 & 1.026$\\pm$0.543 \\\\\n\\cline{1-5}\n\\multirow[t]{2}{*}{\\textbf{1 RFDiff (FASPR)}} & \\textbf{CASP13} ...

# %% [markdown]
# ## Prepare DataFrame

# %%
rfdiff1 = df[df["method"].str.startswith("RF_1_FASPR")]
rfdiff10 = df[df["method"].str.startswith("RF_10_FASPR")]
grp_rdiff1 = (
    rfdiff1[rfdiff1["dataset"] == "CASP14"].groupby(["type", "template"]).agg("first")
)
grp_rdiff10 = (
    rfdiff10[rfdiff10["dataset"] == "CASP14"].groupby(["type", "template"]).agg("first")
)

# %% [markdown]
# ## Plotting constants

# %%
SMALL_SIZE = 30
BIGGER_SIZE = 30
AXES_SIZE = 20
LEGEND_SIZE = 15
plt.rc("font", size=SMALL_SIZE)  # controls default text sizes
plt.rc("axes", titlesize=AXES_SIZE)  # fontsize of the axes title
plt.rc("axes", labelsize=AXES_SIZE)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=AXES_SIZE)  # fontsize of the tick labels
plt.rc("ytick", labelsize=AXES_SIZE)  # fontsize of the tick labels
plt.rc("legend", fontsize=LEGEND_SIZE)  # legend fontsize
plt.rc("figure", titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# ## Plotting RFDiffusion

# %%
fig, (rdiff1, rdiff10) = plt.subplots(1, 2, sharey="row", figsize=(12, 4))
rdiff1.scatter(
    [
        grp_rdiff1.loc["RF_1_FASPR", template]["tm_score"]
        for template in set([temp[1] for temp in grp_rdiff1.index])
    ],
    [
        grp_rdiff1.loc["RF_1_FASPR_AF", template]["tm_score"]
        for template in set([temp[1] for temp in grp_rdiff1.index])
    ],
    s=120,
    alpha=0.5,
)
rdiff1.plot([0.72, 1], [0.72, 1], c="grey")
rdiff1.set_xlabel("Baseline\n\n1 step")
rdiff1.set_ylabel("Post-processed")
rdiff10.scatter(
    [
        grp_rdiff10.loc["RF_10_FASPR", template]["tm_score"]
        for template in set([temp[1] for temp in grp_rdiff10.index])
    ],
    [
        grp_rdiff10.loc["RF_10_FASPR_AF", template]["tm_score"]
        for template in set([temp[1] for temp in grp_rdiff10.index])
    ],
    s=120,
    alpha=0.5,
)
rdiff10.plot([0.72, 1], [0.72, 1], c="grey")
rdiff10.set_xlabel("Baseline\n\n10 steps")
plt.savefig(
    f"visualisations/RF_shared_FASPR_CASP14.svg", bbox_inches="tight", transparent=True
)
plt.show()
plt.clf()

# %% [markdown]
# ## Plotting violin plot constants

# %%
# Some labels need to be changed
order = [
    "MSA",
    "Single",
    "Gaussian",
    "Gaussian (AF)",
    "1 PC",
    "1 PC (AF)",
    "2 PC",
    "2 PC (AF)",
]
measure_dict = {
    "lddt": "lDDT $\\uparrow$",
    "tm_score": "TM-score",
    "af_pLDDT_mean": "pLDDT $\\uparrow$",
    "rmsd": "$\\alpha$-RMSD ($\\AA$) $\\downarrow$",
    "method": "Method",
    "dataset": "Dataset",
}
SMALL_SIZE = 30
BIGGER_SIZE = 30
AXES_SIZE = 20
LEGEND_SIZE = 15
plt.rc("font", size=SMALL_SIZE)  # controls default text sizes
plt.rc("axes", titlesize=AXES_SIZE)  # fontsize of the axes title
plt.rc("axes", labelsize=AXES_SIZE)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=AXES_SIZE)  # fontsize of the tick labels
plt.rc("ytick", labelsize=AXES_SIZE)  # fontsize of the tick labels
plt.rc("legend", fontsize=LEGEND_SIZE)  # legend fontsize
plt.rc("figure", titlesize=BIGGER_SIZE)  # fontsize of the figure title
sns.set_style("whitegrid")

# %% [markdown]
# ## Plotting violin plot

# %%
violin_data = df.drop("method", axis=1).rename(measure_dict, axis=1)
for dataset in ["CASP13", "CASP14"]:
    for metric in ["TM-score", "pLDDT", "$\\alpha$-RMSD ($\\AA$)"]:
        plt.figure(figsize=(14, 10))
        ax = sns.violinplot(
            violin_data[
                (violin_data["Dataset"] == dataset)
                & (violin_data["Method"].isin(order))
            ],
            x="Method",
            hue="Method",
            y=metric,
            linewidth=1,
            palette="tab10",
            order=order,
        )
        plt.setp(ax.collections, alpha=0.5)
        sns.despine(left=True)
        plt.rcParams.update(
            {
                "figure.facecolor": (0.0, 0.0, 0.0, 0.0),
                "axes.facecolor": (0.0, 0.0, 0.0, 0.0),
                "savefig.facecolor": (0.0, 0.0, 0.0, 0.0),
            }
        )
        plt.xticks(rotation=45, ha="right", rotation_mode="anchor")
        plt.savefig(
            f"visualisations/backbone_violin_{dataset}_{metric}.svg",
            bbox_inches="tight",
            transparent=True,
        )
        plt.show()
        plt.clf()

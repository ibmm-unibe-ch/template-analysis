# %% [markdown]
# # Packing_results_with_correlation

# %% [markdown]
# ## Import libraries

# %%
from pathlib import Path
import pickle 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# /tmp/ipykernel_99579/29168323.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Construct table

# %%
methods = [
    "AF_FULL",
    "ATTNPACK",
    "ATTNPACK_AF",
    "BB",
    "BB_AF",
    "BB_PSF",
    "CB_DUMMY",
    "CB_HEURISTIC",
    "FASPR",
    "FASPR_AF",
    "PSF_AF",
    "BB_CB",
    "TEMPLATE_AF",
]
output = []
for dataset in ["CASP13", "CASP14"]:
    dataset_path = Path(dataset)
    for template_path in dataset_path.glob("*.fasta"):
        template = template_path.stem
        for method in methods:
            scores_path = Path(f"{dataset_path}_{method}/{template}/scores.pkl")
            if scores_path.exists():
                with open(scores_path, "rb") as save_file:
                    print(f"read path: {dataset_path}_{method}/{template}/scores.pkl")
                    curr_output = pickle.load(save_file)
                output.append(curr_output)
df = pd.DataFrame(output)
df
# Out:
# read path: CASP13_AF_FULL/T0969/scores.pkl
# read path: CASP13_ATTNPACK/T0969/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0969/scores.pkl
# read path: CASP13_BB/T0969/scores.pkl
# read path: CASP13_BB_PSF/T0969/scores.pkl
# read path: CASP13_CB_DUMMY/T0969/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0969/scores.pkl
# read path: CASP13_FASPR/T0969/scores.pkl
# read path: CASP13_FASPR_AF/T0969/scores.pkl
# read path: CASP13_PSF_AF/T0969/scores.pkl
# read path: CASP13_BB_CB/T0969/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0969/scores.pkl
# read path: CASP13_AF_FULL/T1014/scores.pkl
# read path: CASP13_ATTNPACK/T1014/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1014/scores.pkl
# read path: CASP13_BB/T1014/scores.pkl
# read path: CASP13_BB_PSF/T1014/scores.pkl
# read path: CASP13_CB_DUMMY/T1014/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1014/scores.pkl
# read path: CASP13_FASPR/T1014/scores.pkl
# read path: CASP13_FASPR_AF/T1014/scores.pkl
# read path: CASP13_PSF_AF/T1014/scores.pkl
# read path: CASP13_BB_CB/T1014/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1014/scores.pkl
# read path: CASP13_AF_FULL/T1001/scores.pkl
# read path: CASP13_ATTNPACK/T1001/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1001/scores.pkl
# read path: CASP13_BB/T1001/scores.pkl
# read path: CASP13_BB_PSF/T1001/scores.pkl
# read path: CASP13_CB_DUMMY/T1001/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1001/scores.pkl
# read path: CASP13_FASPR/T1001/scores.pkl
# read path: CASP13_FASPR_AF/T1001/scores.pkl
# read path: CASP13_PSF_AF/T1001/scores.pkl
# read path: CASP13_BB_CB/T1001/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1001/scores.pkl
# read path: CASP13_AF_FULL/T0974s1/scores.pkl
# read path: CASP13_ATTNPACK/T0974s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0974s1/scores.pkl
# read path: CASP13_BB/T0974s1/scores.pkl
# read path: CASP13_BB_PSF/T0974s1/scores.pkl
# read path: CASP13_CB_DUMMY/T0974s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0974s1/scores.pkl
# read path: CASP13_FASPR/T0974s1/scores.pkl
# read path: CASP13_FASPR_AF/T0974s1/scores.pkl
# read path: CASP13_PSF_AF/T0974s1/scores.pkl
# read path: CASP13_BB_CB/T0974s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0974s1/scores.pkl
# read path: CASP13_AF_FULL/T1017s2/scores.pkl
# read path: CASP13_ATTNPACK/T1017s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1017s2/scores.pkl
# read path: CASP13_BB/T1017s2/scores.pkl
# read path: CASP13_BB_PSF/T1017s2/scores.pkl
# read path: CASP13_CB_DUMMY/T1017s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1017s2/scores.pkl
# read path: CASP13_FASPR/T1017s2/scores.pkl
# read path: CASP13_FASPR_AF/T1017s2/scores.pkl
# read path: CASP13_PSF_AF/T1017s2/scores.pkl
# read path: CASP13_BB_CB/T1017s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1017s2/scores.pkl
# read path: CASP13_AF_FULL/T0993s2/scores.pkl
# read path: CASP13_ATTNPACK/T0993s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0993s2/scores.pkl
# read path: CASP13_BB/T0993s2/scores.pkl
# read path: CASP13_BB_PSF/T0993s2/scores.pkl
# read path: CASP13_CB_DUMMY/T0993s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0993s2/scores.pkl
# read path: CASP13_FASPR/T0993s2/scores.pkl
# read path: CASP13_FASPR_AF/T0993s2/scores.pkl
# read path: CASP13_PSF_AF/T0993s2/scores.pkl
# read path: CASP13_BB_CB/T0993s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0993s2/scores.pkl
# read path: CASP13_AF_FULL/T0983/scores.pkl
# read path: CASP13_ATTNPACK/T0983/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0983/scores.pkl
# read path: CASP13_BB/T0983/scores.pkl
# read path: CASP13_BB_PSF/T0983/scores.pkl
# read path: CASP13_CB_DUMMY/T0983/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0983/scores.pkl
# read path: CASP13_FASPR/T0983/scores.pkl
# read path: CASP13_FASPR_AF/T0983/scores.pkl
# read path: CASP13_PSF_AF/T0983/scores.pkl
# read path: CASP13_BB_CB/T0983/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0983/scores.pkl
# read path: CASP13_AF_FULL/T1015s2/scores.pkl
# read path: CASP13_ATTNPACK/T1015s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1015s2/scores.pkl
# read path: CASP13_BB/T1015s2/scores.pkl
# read path: CASP13_BB_PSF/T1015s2/scores.pkl
# read path: CASP13_CB_DUMMY/T1015s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1015s2/scores.pkl
# read path: CASP13_FASPR/T1015s2/scores.pkl
# read path: CASP13_FASPR_AF/T1015s2/scores.pkl
# read path: CASP13_PSF_AF/T1015s2/scores.pkl
# read path: CASP13_BB_CB/T1015s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1015s2/scores.pkl
# read path: CASP13_AF_FULL/T1021s1/scores.pkl
# read path: CASP13_ATTNPACK/T1021s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1021s1/scores.pkl
# read path: CASP13_BB/T1021s1/scores.pkl
# read path: CASP13_BB_PSF/T1021s1/scores.pkl
# read path: CASP13_CB_DUMMY/T1021s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1021s1/scores.pkl
# read path: CASP13_FASPR/T1021s1/scores.pkl
# read path: CASP13_FASPR_AF/T1021s1/scores.pkl
# read path: CASP13_PSF_AF/T1021s1/scores.pkl
# read path: CASP13_BB_CB/T1021s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1021s1/scores.pkl
# read path: CASP13_AF_FULL/T0980s1/scores.pkl
# read path: CASP13_ATTNPACK/T0980s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0980s1/scores.pkl
# read path: CASP13_BB/T0980s1/scores.pkl
# read path: CASP13_BB_PSF/T0980s1/scores.pkl
# read path: CASP13_CB_DUMMY/T0980s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0980s1/scores.pkl
# read path: CASP13_FASPR/T0980s1/scores.pkl
# read path: CASP13_FASPR_AF/T0980s1/scores.pkl
# read path: CASP13_PSF_AF/T0980s1/scores.pkl
# read path: CASP13_BB_CB/T0980s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0980s1/scores.pkl
# read path: CASP13_AF_FULL/T0965/scores.pkl
# read path: CASP13_ATTNPACK/T0965/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0965/scores.pkl
# read path: CASP13_BB/T0965/scores.pkl
# read path: CASP13_BB_PSF/T0965/scores.pkl
# read path: CASP13_CB_DUMMY/T0965/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0965/scores.pkl
# read path: CASP13_FASPR/T0965/scores.pkl
# read path: CASP13_FASPR_AF/T0965/scores.pkl
# read path: CASP13_PSF_AF/T0965/scores.pkl
# read path: CASP13_BB_CB/T0965/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0965/scores.pkl
# read path: CASP13_AF_FULL/T0997/scores.pkl
# read path: CASP13_ATTNPACK/T0997/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0997/scores.pkl
# read path: CASP13_BB/T0997/scores.pkl
# read path: CASP13_BB_PSF/T0997/scores.pkl
# read path: CASP13_CB_DUMMY/T0997/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0997/scores.pkl
# read path: CASP13_FASPR/T0997/scores.pkl
# read path: CASP13_FASPR_AF/T0997/scores.pkl
# read path: CASP13_PSF_AF/T0997/scores.pkl
# read path: CASP13_BB_CB/T0997/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0997/scores.pkl
# read path: CASP13_AF_FULL/T0963/scores.pkl
# read path: CASP13_ATTNPACK/T0963/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0963/scores.pkl
# read path: CASP13_BB/T0963/scores.pkl
# read path: CASP13_BB_PSF/T0963/scores.pkl
# read path: CASP13_CB_DUMMY/T0963/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0963/scores.pkl
# read path: CASP13_FASPR/T0963/scores.pkl
# read path: CASP13_FASPR_AF/T0963/scores.pkl
# read path: CASP13_PSF_AF/T0963/scores.pkl
# read path: CASP13_BB_CB/T0963/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0963/scores.pkl
# read path: CASP13_AF_FULL/T0968s2/scores.pkl
# read path: CASP13_ATTNPACK/T0968s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0968s2/scores.pkl
# read path: CASP13_BB/T0968s2/scores.pkl
# read path: CASP13_BB_PSF/T0968s2/scores.pkl
# read path: CASP13_CB_DUMMY/T0968s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0968s2/scores.pkl
# read path: CASP13_FASPR/T0968s2/scores.pkl
# read path: CASP13_FASPR_AF/T0968s2/scores.pkl
# read path: CASP13_PSF_AF/T0968s2/scores.pkl
# read path: CASP13_BB_CB/T0968s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0968s2/scores.pkl
# read path: CASP13_AF_FULL/T0996/scores.pkl
# read path: CASP13_ATTNPACK/T0996/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0996/scores.pkl
# read path: CASP13_BB/T0996/scores.pkl
# read path: CASP13_BB_PSF/T0996/scores.pkl
# read path: CASP13_CB_DUMMY/T0996/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0996/scores.pkl
# read path: CASP13_FASPR/T0996/scores.pkl
# read path: CASP13_FASPR_AF/T0996/scores.pkl
# read path: CASP13_PSF_AF/T0996/scores.pkl
# read path: CASP13_BB_CB/T0996/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0996/scores.pkl
# read path: CASP13_AF_FULL/T0984/scores.pkl
# read path: CASP13_ATTNPACK/T0984/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0984/scores.pkl
# read path: CASP13_BB/T0984/scores.pkl
# read path: CASP13_BB_PSF/T0984/scores.pkl
# read path: CASP13_CB_DUMMY/T0984/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0984/scores.pkl
# read path: CASP13_FASPR/T0984/scores.pkl
# read path: CASP13_FASPR_AF/T0984/scores.pkl
# read path: CASP13_PSF_AF/T0984/scores.pkl
# read path: CASP13_BB_CB/T0984/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0984/scores.pkl
# read path: CASP13_AF_FULL/T1002/scores.pkl
# read path: CASP13_ATTNPACK/T1002/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1002/scores.pkl
# read path: CASP13_BB/T1002/scores.pkl
# read path: CASP13_BB_PSF/T1002/scores.pkl
# read path: CASP13_CB_DUMMY/T1002/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1002/scores.pkl
# read path: CASP13_FASPR/T1002/scores.pkl
# read path: CASP13_FASPR_AF/T1002/scores.pkl
# read path: CASP13_PSF_AF/T1002/scores.pkl
# read path: CASP13_BB_CB/T1002/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1002/scores.pkl
# read path: CASP13_AF_FULL/T0974s2/scores.pkl
# read path: CASP13_ATTNPACK/T0974s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0974s2/scores.pkl
# read path: CASP13_BB/T0974s2/scores.pkl
# read path: CASP13_BB_PSF/T0974s2/scores.pkl
# read path: CASP13_CB_DUMMY/T0974s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0974s2/scores.pkl
# read path: CASP13_FASPR/T0974s2/scores.pkl
# read path: CASP13_FASPR_AF/T0974s2/scores.pkl
# read path: CASP13_PSF_AF/T0974s2/scores.pkl
# read path: CASP13_BB_CB/T0974s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0974s2/scores.pkl
# read path: CASP13_AF_FULL/T1020/scores.pkl
# read path: CASP13_ATTNPACK/T1020/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1020/scores.pkl
# read path: CASP13_BB/T1020/scores.pkl
# read path: CASP13_BB_PSF/T1020/scores.pkl
# read path: CASP13_CB_DUMMY/T1020/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1020/scores.pkl
# read path: CASP13_FASPR/T1020/scores.pkl
# read path: CASP13_FASPR_AF/T1020/scores.pkl
# read path: CASP13_PSF_AF/T1020/scores.pkl
# read path: CASP13_BB_CB/T1020/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1020/scores.pkl
# read path: CASP13_AF_FULL/T0949/scores.pkl
# read path: CASP13_ATTNPACK/T0949/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0949/scores.pkl
# read path: CASP13_BB/T0949/scores.pkl
# read path: CASP13_BB_PSF/T0949/scores.pkl
# read path: CASP13_CB_DUMMY/T0949/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0949/scores.pkl
# read path: CASP13_FASPR/T0949/scores.pkl
# read path: CASP13_FASPR_AF/T0949/scores.pkl
# read path: CASP13_PSF_AF/T0949/scores.pkl
# read path: CASP13_BB_CB/T0949/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0949/scores.pkl
# read path: CASP13_AF_FULL/T1004/scores.pkl
# read path: CASP13_ATTNPACK/T1004/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1004/scores.pkl
# read path: CASP13_BB/T1004/scores.pkl
# read path: CASP13_BB_PSF/T1004/scores.pkl
# read path: CASP13_CB_DUMMY/T1004/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1004/scores.pkl
# read path: CASP13_FASPR/T1004/scores.pkl
# read path: CASP13_FASPR_AF/T1004/scores.pkl
# read path: CASP13_PSF_AF/T1004/scores.pkl
# read path: CASP13_BB_CB/T1004/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1004/scores.pkl
# read path: CASP13_AF_FULL/T0994/scores.pkl
# read path: CASP13_ATTNPACK/T0994/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0994/scores.pkl
# read path: CASP13_BB/T0994/scores.pkl
# read path: CASP13_BB_PSF/T0994/scores.pkl
# read path: CASP13_CB_DUMMY/T0994/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0994/scores.pkl
# read path: CASP13_FASPR/T0994/scores.pkl
# read path: CASP13_FASPR_AF/T0994/scores.pkl
# read path: CASP13_PSF_AF/T0994/scores.pkl
# read path: CASP13_BB_CB/T0994/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0994/scores.pkl
# read path: CASP13_AF_FULL/T0991/scores.pkl
# read path: CASP13_ATTNPACK/T0991/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0991/scores.pkl
# read path: CASP13_BB/T0991/scores.pkl
# read path: CASP13_BB_PSF/T0991/scores.pkl
# read path: CASP13_CB_DUMMY/T0991/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0991/scores.pkl
# read path: CASP13_FASPR/T0991/scores.pkl
# read path: CASP13_FASPR_AF/T0991/scores.pkl
# read path: CASP13_PSF_AF/T0991/scores.pkl
# read path: CASP13_BB_CB/T0991/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0991/scores.pkl
# read path: CASP13_AF_FULL/T1005/scores.pkl
# read path: CASP13_ATTNPACK/T1005/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1005/scores.pkl
# read path: CASP13_BB/T1005/scores.pkl
# read path: CASP13_BB_PSF/T1005/scores.pkl
# read path: CASP13_CB_DUMMY/T1005/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1005/scores.pkl
# read path: CASP13_FASPR/T1005/scores.pkl
# read path: CASP13_FASPR_AF/T1005/scores.pkl
# read path: CASP13_PSF_AF/T1005/scores.pkl
# read path: CASP13_BB_CB/T1005/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1005/scores.pkl
# read path: CASP13_AF_FULL/T0968s1/scores.pkl
# read path: CASP13_ATTNPACK/T0968s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0968s1/scores.pkl
# read path: CASP13_BB/T0968s1/scores.pkl
# read path: CASP13_BB_PSF/T0968s1/scores.pkl
# read path: CASP13_CB_DUMMY/T0968s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0968s1/scores.pkl
# read path: CASP13_FASPR/T0968s1/scores.pkl
# read path: CASP13_FASPR_AF/T0968s1/scores.pkl
# read path: CASP13_PSF_AF/T0968s1/scores.pkl
# read path: CASP13_BB_CB/T0968s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0968s1/scores.pkl
# read path: CASP13_AF_FULL/T0970/scores.pkl
# read path: CASP13_ATTNPACK/T0970/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0970/scores.pkl
# read path: CASP13_BB/T0970/scores.pkl
# read path: CASP13_BB_PSF/T0970/scores.pkl
# read path: CASP13_CB_DUMMY/T0970/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0970/scores.pkl
# read path: CASP13_FASPR/T0970/scores.pkl
# read path: CASP13_FASPR_AF/T0970/scores.pkl
# read path: CASP13_PSF_AF/T0970/scores.pkl
# read path: CASP13_BB_CB/T0970/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0970/scores.pkl
# read path: CASP13_AF_FULL/T1006/scores.pkl
# read path: CASP13_ATTNPACK/T1006/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1006/scores.pkl
# read path: CASP13_BB/T1006/scores.pkl
# read path: CASP13_BB_PSF/T1006/scores.pkl
# read path: CASP13_CB_DUMMY/T1006/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1006/scores.pkl
# read path: CASP13_FASPR/T1006/scores.pkl
# read path: CASP13_FASPR_AF/T1006/scores.pkl
# read path: CASP13_PSF_AF/T1006/scores.pkl
# read path: CASP13_BB_CB/T1006/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1006/scores.pkl
# read path: CASP13_AF_FULL/T1013/scores.pkl
# read path: CASP13_ATTNPACK/T1013/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1013/scores.pkl
# read path: CASP13_BB/T1013/scores.pkl
# read path: CASP13_BB_PSF/T1013/scores.pkl
# read path: CASP13_CB_DUMMY/T1013/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1013/scores.pkl
# read path: CASP13_FASPR/T1013/scores.pkl
# read path: CASP13_FASPR_AF/T1013/scores.pkl
# read path: CASP13_PSF_AF/T1013/scores.pkl
# read path: CASP13_BB_CB/T1013/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1013/scores.pkl
# read path: CASP13_AF_FULL/T1022s1/scores.pkl
# read path: CASP13_ATTNPACK/T1022s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1022s1/scores.pkl
# read path: CASP13_BB/T1022s1/scores.pkl
# read path: CASP13_BB_PSF/T1022s1/scores.pkl
# read path: CASP13_CB_DUMMY/T1022s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1022s1/scores.pkl
# read path: CASP13_FASPR/T1022s1/scores.pkl
# read path: CASP13_FASPR_AF/T1022s1/scores.pkl
# read path: CASP13_PSF_AF/T1022s1/scores.pkl
# read path: CASP13_BB_CB/T1022s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1022s1/scores.pkl
# read path: CASP13_AF_FULL/T0976/scores.pkl
# read path: CASP13_ATTNPACK/T0976/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0976/scores.pkl
# read path: CASP13_BB/T0976/scores.pkl
# read path: CASP13_BB_PSF/T0976/scores.pkl
# read path: CASP13_CB_DUMMY/T0976/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0976/scores.pkl
# read path: CASP13_FASPR/T0976/scores.pkl
# read path: CASP13_FASPR_AF/T0976/scores.pkl
# read path: CASP13_PSF_AF/T0976/scores.pkl
# read path: CASP13_BB_CB/T0976/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0976/scores.pkl
# read path: CASP13_AF_FULL/T0989/scores.pkl
# read path: CASP13_ATTNPACK/T0989/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0989/scores.pkl
# read path: CASP13_BB/T0989/scores.pkl
# read path: CASP13_BB_PSF/T0989/scores.pkl
# read path: CASP13_CB_DUMMY/T0989/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0989/scores.pkl
# read path: CASP13_FASPR/T0989/scores.pkl
# read path: CASP13_FASPR_AF/T0989/scores.pkl
# read path: CASP13_PSF_AF/T0989/scores.pkl
# read path: CASP13_BB_CB/T0989/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0989/scores.pkl
# read path: CASP13_AF_FULL/T0957s2/scores.pkl
# read path: CASP13_ATTNPACK/T0957s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0957s2/scores.pkl
# read path: CASP13_BB/T0957s2/scores.pkl
# read path: CASP13_BB_PSF/T0957s2/scores.pkl
# read path: CASP13_CB_DUMMY/T0957s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0957s2/scores.pkl
# read path: CASP13_FASPR/T0957s2/scores.pkl
# read path: CASP13_FASPR_AF/T0957s2/scores.pkl
# read path: CASP13_PSF_AF/T0957s2/scores.pkl
# read path: CASP13_BB_CB/T0957s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0957s2/scores.pkl
# read path: CASP13_AF_FULL/T1010/scores.pkl
# read path: CASP13_ATTNPACK/T1010/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1010/scores.pkl
# read path: CASP13_BB/T1010/scores.pkl
# read path: CASP13_BB_PSF/T1010/scores.pkl
# read path: CASP13_CB_DUMMY/T1010/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1010/scores.pkl
# read path: CASP13_FASPR/T1010/scores.pkl
# read path: CASP13_FASPR_AF/T1010/scores.pkl
# read path: CASP13_PSF_AF/T1010/scores.pkl
# read path: CASP13_BB_CB/T1010/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1010/scores.pkl
# read path: CASP13_AF_FULL/T1017s1/scores.pkl
# read path: CASP13_ATTNPACK/T1017s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1017s1/scores.pkl
# read path: CASP13_BB/T1017s1/scores.pkl
# read path: CASP13_BB_PSF/T1017s1/scores.pkl
# read path: CASP13_CB_DUMMY/T1017s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1017s1/scores.pkl
# read path: CASP13_FASPR/T1017s1/scores.pkl
# read path: CASP13_FASPR_AF/T1017s1/scores.pkl
# read path: CASP13_PSF_AF/T1017s1/scores.pkl
# read path: CASP13_BB_CB/T1017s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1017s1/scores.pkl
# read path: CASP13_AF_FULL/T1018/scores.pkl
# read path: CASP13_ATTNPACK/T1018/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1018/scores.pkl
# read path: CASP13_BB/T1018/scores.pkl
# read path: CASP13_BB_PSF/T1018/scores.pkl
# read path: CASP13_CB_DUMMY/T1018/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1018/scores.pkl
# read path: CASP13_FASPR/T1018/scores.pkl
# read path: CASP13_FASPR_AF/T1018/scores.pkl
# read path: CASP13_PSF_AF/T1018/scores.pkl
# read path: CASP13_BB_CB/T1018/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1018/scores.pkl
# read path: CASP13_AF_FULL/T0953s1/scores.pkl
# read path: CASP13_ATTNPACK/T0953s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0953s1/scores.pkl
# read path: CASP13_BB/T0953s1/scores.pkl
# read path: CASP13_BB_PSF/T0953s1/scores.pkl
# read path: CASP13_CB_DUMMY/T0953s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0953s1/scores.pkl
# read path: CASP13_FASPR/T0953s1/scores.pkl
# read path: CASP13_FASPR_AF/T0953s1/scores.pkl
# read path: CASP13_PSF_AF/T0953s1/scores.pkl
# read path: CASP13_BB_CB/T0953s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0953s1/scores.pkl
# read path: CASP13_AF_FULL/T0995/scores.pkl
# read path: CASP13_ATTNPACK/T0995/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0995/scores.pkl
# read path: CASP13_BB/T0995/scores.pkl
# read path: CASP13_BB_PSF/T0995/scores.pkl
# read path: CASP13_CB_DUMMY/T0995/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0995/scores.pkl
# read path: CASP13_FASPR/T0995/scores.pkl
# read path: CASP13_FASPR_AF/T0995/scores.pkl
# read path: CASP13_PSF_AF/T0995/scores.pkl
# read path: CASP13_BB_CB/T0995/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0995/scores.pkl
# read path: CASP13_AF_FULL/T0979/scores.pkl
# read path: CASP13_ATTNPACK/T0979/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0979/scores.pkl
# read path: CASP13_BB/T0979/scores.pkl
# read path: CASP13_BB_PSF/T0979/scores.pkl
# read path: CASP13_CB_DUMMY/T0979/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0979/scores.pkl
# read path: CASP13_FASPR/T0979/scores.pkl
# read path: CASP13_FASPR_AF/T0979/scores.pkl
# read path: CASP13_PSF_AF/T0979/scores.pkl
# read path: CASP13_BB_CB/T0979/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0979/scores.pkl
# read path: CASP13_AF_FULL/T1021s3/scores.pkl
# read path: CASP13_ATTNPACK/T1021s3/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1021s3/scores.pkl
# read path: CASP13_BB/T1021s3/scores.pkl
# read path: CASP13_BB_PSF/T1021s3/scores.pkl
# read path: CASP13_CB_DUMMY/T1021s3/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1021s3/scores.pkl
# read path: CASP13_FASPR/T1021s3/scores.pkl
# read path: CASP13_FASPR_AF/T1021s3/scores.pkl
# read path: CASP13_PSF_AF/T1021s3/scores.pkl
# read path: CASP13_BB_CB/T1021s3/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1021s3/scores.pkl
# read path: CASP13_AF_FULL/T0961/scores.pkl
# read path: CASP13_ATTNPACK/T0961/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0961/scores.pkl
# read path: CASP13_BB/T0961/scores.pkl
# read path: CASP13_BB_PSF/T0961/scores.pkl
# read path: CASP13_CB_DUMMY/T0961/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0961/scores.pkl
# read path: CASP13_FASPR/T0961/scores.pkl
# read path: CASP13_FASPR_AF/T0961/scores.pkl
# read path: CASP13_PSF_AF/T0961/scores.pkl
# read path: CASP13_BB_CB/T0961/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0961/scores.pkl
# read path: CASP13_AF_FULL/T0992/scores.pkl
# read path: CASP13_ATTNPACK/T0992/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0992/scores.pkl
# read path: CASP13_BB/T0992/scores.pkl
# read path: CASP13_BB_PSF/T0992/scores.pkl
# read path: CASP13_CB_DUMMY/T0992/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0992/scores.pkl
# read path: CASP13_FASPR/T0992/scores.pkl
# read path: CASP13_FASPR_AF/T0992/scores.pkl
# read path: CASP13_PSF_AF/T0992/scores.pkl
# read path: CASP13_BB_CB/T0992/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0992/scores.pkl
# read path: CASP13_AF_FULL/T0977/scores.pkl
# read path: CASP13_ATTNPACK/T0977/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0977/scores.pkl
# read path: CASP13_BB/T0977/scores.pkl
# read path: CASP13_BB_PSF/T0977/scores.pkl
# read path: CASP13_CB_DUMMY/T0977/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0977/scores.pkl
# read path: CASP13_FASPR/T0977/scores.pkl
# read path: CASP13_FASPR_AF/T0977/scores.pkl
# read path: CASP13_PSF_AF/T0977/scores.pkl
# read path: CASP13_BB_CB/T0977/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0977/scores.pkl
# read path: CASP13_AF_FULL/T0998/scores.pkl
# read path: CASP13_ATTNPACK/T0998/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0998/scores.pkl
# read path: CASP13_BB/T0998/scores.pkl
# read path: CASP13_BB_PSF/T0998/scores.pkl
# read path: CASP13_CB_DUMMY/T0998/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0998/scores.pkl
# read path: CASP13_FASPR/T0998/scores.pkl
# read path: CASP13_FASPR_AF/T0998/scores.pkl
# read path: CASP13_PSF_AF/T0998/scores.pkl
# read path: CASP13_BB_CB/T0998/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0998/scores.pkl
# read path: CASP13_AF_FULL/T0978/scores.pkl
# read path: CASP13_ATTNPACK/T0978/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0978/scores.pkl
# read path: CASP13_BB/T0978/scores.pkl
# read path: CASP13_BB_PSF/T0978/scores.pkl
# read path: CASP13_CB_DUMMY/T0978/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0978/scores.pkl
# read path: CASP13_FASPR/T0978/scores.pkl
# read path: CASP13_FASPR_AF/T0978/scores.pkl
# read path: CASP13_PSF_AF/T0978/scores.pkl
# read path: CASP13_BB_CB/T0978/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0978/scores.pkl
# read path: CASP13_AF_FULL/T1019s2/scores.pkl
# read path: CASP13_ATTNPACK/T1019s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1019s2/scores.pkl
# read path: CASP13_BB/T1019s2/scores.pkl
# read path: CASP13_BB_PSF/T1019s2/scores.pkl
# read path: CASP13_CB_DUMMY/T1019s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1019s2/scores.pkl
# read path: CASP13_FASPR/T1019s2/scores.pkl
# read path: CASP13_FASPR_AF/T1019s2/scores.pkl
# read path: CASP13_PSF_AF/T1019s2/scores.pkl
# read path: CASP13_BB_CB/T1019s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1019s2/scores.pkl
# read path: CASP13_AF_FULL/T1011/scores.pkl
# read path: CASP13_ATTNPACK/T1011/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1011/scores.pkl
# read path: CASP13_BB/T1011/scores.pkl
# read path: CASP13_BB_PSF/T1011/scores.pkl
# read path: CASP13_CB_DUMMY/T1011/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1011/scores.pkl
# read path: CASP13_FASPR/T1011/scores.pkl
# read path: CASP13_FASPR_AF/T1011/scores.pkl
# read path: CASP13_PSF_AF/T1011/scores.pkl
# read path: CASP13_BB_CB/T1011/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1011/scores.pkl
# read path: CASP13_AF_FULL/T0950/scores.pkl
# read path: CASP13_ATTNPACK/T0950/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0950/scores.pkl
# read path: CASP13_BB/T0950/scores.pkl
# read path: CASP13_BB_PSF/T0950/scores.pkl
# read path: CASP13_CB_DUMMY/T0950/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0950/scores.pkl
# read path: CASP13_FASPR/T0950/scores.pkl
# read path: CASP13_FASPR_AF/T0950/scores.pkl
# read path: CASP13_PSF_AF/T0950/scores.pkl
# read path: CASP13_BB_CB/T0950/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0950/scores.pkl
# read path: CASP13_AF_FULL/T0964/scores.pkl
# read path: CASP13_ATTNPACK/T0964/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0964/scores.pkl
# read path: CASP13_BB/T0964/scores.pkl
# read path: CASP13_BB_PSF/T0964/scores.pkl
# read path: CASP13_CB_DUMMY/T0964/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0964/scores.pkl
# read path: CASP13_FASPR/T0964/scores.pkl
# read path: CASP13_FASPR_AF/T0964/scores.pkl
# read path: CASP13_PSF_AF/T0964/scores.pkl
# read path: CASP13_BB_CB/T0964/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0964/scores.pkl
# read path: CASP13_AF_FULL/T0990/scores.pkl
# read path: CASP13_ATTNPACK/T0990/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0990/scores.pkl
# read path: CASP13_BB/T0990/scores.pkl
# read path: CASP13_BB_PSF/T0990/scores.pkl
# read path: CASP13_CB_DUMMY/T0990/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0990/scores.pkl
# read path: CASP13_FASPR/T0990/scores.pkl
# read path: CASP13_FASPR_AF/T0990/scores.pkl
# read path: CASP13_PSF_AF/T0990/scores.pkl
# read path: CASP13_BB_CB/T0990/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0990/scores.pkl
# read path: CASP13_AF_FULL/T0973/scores.pkl
# read path: CASP13_ATTNPACK/T0973/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0973/scores.pkl
# read path: CASP13_BB/T0973/scores.pkl
# read path: CASP13_BB_PSF/T0973/scores.pkl
# read path: CASP13_CB_DUMMY/T0973/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0973/scores.pkl
# read path: CASP13_FASPR/T0973/scores.pkl
# read path: CASP13_FASPR_AF/T0973/scores.pkl
# read path: CASP13_PSF_AF/T0973/scores.pkl
# read path: CASP13_BB_CB/T0973/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0973/scores.pkl
# read path: CASP13_AF_FULL/T0957s1/scores.pkl
# read path: CASP13_ATTNPACK/T0957s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0957s1/scores.pkl
# read path: CASP13_BB/T0957s1/scores.pkl
# read path: CASP13_BB_PSF/T0957s1/scores.pkl
# read path: CASP13_CB_DUMMY/T0957s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0957s1/scores.pkl
# read path: CASP13_FASPR/T0957s1/scores.pkl
# read path: CASP13_FASPR_AF/T0957s1/scores.pkl
# read path: CASP13_PSF_AF/T0957s1/scores.pkl
# read path: CASP13_BB_CB/T0957s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0957s1/scores.pkl
# read path: CASP13_AF_FULL/T0971/scores.pkl
# read path: CASP13_ATTNPACK/T0971/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0971/scores.pkl
# read path: CASP13_BB/T0971/scores.pkl
# read path: CASP13_BB_PSF/T0971/scores.pkl
# read path: CASP13_CB_DUMMY/T0971/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0971/scores.pkl
# read path: CASP13_FASPR/T0971/scores.pkl
# read path: CASP13_FASPR_AF/T0971/scores.pkl
# read path: CASP13_PSF_AF/T0971/scores.pkl
# read path: CASP13_BB_CB/T0971/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0971/scores.pkl
# read path: CASP13_AF_FULL/T0954/scores.pkl
# read path: CASP13_ATTNPACK/T0954/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0954/scores.pkl
# read path: CASP13_BB/T0954/scores.pkl
# read path: CASP13_BB_PSF/T0954/scores.pkl
# read path: CASP13_CB_DUMMY/T0954/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0954/scores.pkl
# read path: CASP13_FASPR/T0954/scores.pkl
# read path: CASP13_FASPR_AF/T0954/scores.pkl
# read path: CASP13_PSF_AF/T0954/scores.pkl
# read path: CASP13_BB_CB/T0954/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0954/scores.pkl
# read path: CASP13_AF_FULL/T0958/scores.pkl
# read path: CASP13_ATTNPACK/T0958/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0958/scores.pkl
# read path: CASP13_BB/T0958/scores.pkl
# read path: CASP13_BB_PSF/T0958/scores.pkl
# read path: CASP13_CB_DUMMY/T0958/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0958/scores.pkl
# read path: CASP13_FASPR/T0958/scores.pkl
# read path: CASP13_FASPR_AF/T0958/scores.pkl
# read path: CASP13_PSF_AF/T0958/scores.pkl
# read path: CASP13_BB_CB/T0958/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0958/scores.pkl
# read path: CASP13_AF_FULL/T1000/scores.pkl
# read path: CASP13_ATTNPACK/T1000/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1000/scores.pkl
# read path: CASP13_BB/T1000/scores.pkl
# read path: CASP13_BB_PSF/T1000/scores.pkl
# read path: CASP13_CB_DUMMY/T1000/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1000/scores.pkl
# read path: CASP13_FASPR/T1000/scores.pkl
# read path: CASP13_FASPR_AF/T1000/scores.pkl
# read path: CASP13_PSF_AF/T1000/scores.pkl
# read path: CASP13_BB_CB/T1000/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1000/scores.pkl
# read path: CASP13_AF_FULL/T1008/scores.pkl
# read path: CASP13_ATTNPACK/T1008/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1008/scores.pkl
# read path: CASP13_BB/T1008/scores.pkl
# read path: CASP13_BB_PSF/T1008/scores.pkl
# read path: CASP13_CB_DUMMY/T1008/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1008/scores.pkl
# read path: CASP13_FASPR/T1008/scores.pkl
# read path: CASP13_FASPR_AF/T1008/scores.pkl
# read path: CASP13_PSF_AF/T1008/scores.pkl
# read path: CASP13_BB_CB/T1008/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1008/scores.pkl
# read path: CASP13_AF_FULL/T1022s2/scores.pkl
# read path: CASP13_ATTNPACK/T1022s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1022s2/scores.pkl
# read path: CASP13_BB/T1022s2/scores.pkl
# read path: CASP13_BB_PSF/T1022s2/scores.pkl
# read path: CASP13_CB_DUMMY/T1022s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1022s2/scores.pkl
# read path: CASP13_FASPR/T1022s2/scores.pkl
# read path: CASP13_FASPR_AF/T1022s2/scores.pkl
# read path: CASP13_PSF_AF/T1022s2/scores.pkl
# read path: CASP13_BB_CB/T1022s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1022s2/scores.pkl
# read path: CASP13_AF_FULL/T1016/scores.pkl
# read path: CASP13_ATTNPACK/T1016/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1016/scores.pkl
# read path: CASP13_BB/T1016/scores.pkl
# read path: CASP13_BB_PSF/T1016/scores.pkl
# read path: CASP13_CB_DUMMY/T1016/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1016/scores.pkl
# read path: CASP13_FASPR/T1016/scores.pkl
# read path: CASP13_FASPR_AF/T1016/scores.pkl
# read path: CASP13_PSF_AF/T1016/scores.pkl
# read path: CASP13_BB_CB/T1016/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1016/scores.pkl
# read path: CASP13_AF_FULL/T0959/scores.pkl
# read path: CASP13_ATTNPACK/T0959/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0959/scores.pkl
# read path: CASP13_BB/T0959/scores.pkl
# read path: CASP13_BB_PSF/T0959/scores.pkl
# read path: CASP13_CB_DUMMY/T0959/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0959/scores.pkl
# read path: CASP13_FASPR/T0959/scores.pkl
# read path: CASP13_FASPR_AF/T0959/scores.pkl
# read path: CASP13_PSF_AF/T0959/scores.pkl
# read path: CASP13_BB_CB/T0959/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0959/scores.pkl
# read path: CASP13_AF_FULL/T0982/scores.pkl
# read path: CASP13_ATTNPACK/T0982/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0982/scores.pkl
# read path: CASP13_BB/T0982/scores.pkl
# read path: CASP13_BB_PSF/T0982/scores.pkl
# read path: CASP13_CB_DUMMY/T0982/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0982/scores.pkl
# read path: CASP13_FASPR/T0982/scores.pkl
# read path: CASP13_FASPR_AF/T0982/scores.pkl
# read path: CASP13_PSF_AF/T0982/scores.pkl
# read path: CASP13_BB_CB/T0982/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0982/scores.pkl
# read path: CASP13_AF_FULL/T0986s2/scores.pkl
# read path: CASP13_ATTNPACK/T0986s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0986s2/scores.pkl
# read path: CASP13_BB/T0986s2/scores.pkl
# read path: CASP13_BB_PSF/T0986s2/scores.pkl
# read path: CASP13_CB_DUMMY/T0986s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0986s2/scores.pkl
# read path: CASP13_FASPR/T0986s2/scores.pkl
# read path: CASP13_FASPR_AF/T0986s2/scores.pkl
# read path: CASP13_PSF_AF/T0986s2/scores.pkl
# read path: CASP13_BB_CB/T0986s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0986s2/scores.pkl
# read path: CASP13_AF_FULL/T0966/scores.pkl
# read path: CASP13_ATTNPACK/T0966/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0966/scores.pkl
# read path: CASP13_BB/T0966/scores.pkl
# read path: CASP13_BB_PSF/T0966/scores.pkl
# read path: CASP13_CB_DUMMY/T0966/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0966/scores.pkl
# read path: CASP13_FASPR/T0966/scores.pkl
# read path: CASP13_FASPR_AF/T0966/scores.pkl
# read path: CASP13_PSF_AF/T0966/scores.pkl
# read path: CASP13_BB_CB/T0966/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0966/scores.pkl
# read path: CASP13_AF_FULL/T0975/scores.pkl
# read path: CASP13_ATTNPACK/T0975/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0975/scores.pkl
# read path: CASP13_BB/T0975/scores.pkl
# read path: CASP13_BB_PSF/T0975/scores.pkl
# read path: CASP13_CB_DUMMY/T0975/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0975/scores.pkl
# read path: CASP13_FASPR/T0975/scores.pkl
# read path: CASP13_FASPR_AF/T0975/scores.pkl
# read path: CASP13_PSF_AF/T0975/scores.pkl
# read path: CASP13_BB_CB/T0975/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0975/scores.pkl
# read path: CASP13_AF_FULL/T1015s1/scores.pkl
# read path: CASP13_ATTNPACK/T1015s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1015s1/scores.pkl
# read path: CASP13_BB/T1015s1/scores.pkl
# read path: CASP13_BB_PSF/T1015s1/scores.pkl
# read path: CASP13_CB_DUMMY/T1015s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1015s1/scores.pkl
# read path: CASP13_FASPR/T1015s1/scores.pkl
# read path: CASP13_FASPR_AF/T1015s1/scores.pkl
# read path: CASP13_PSF_AF/T1015s1/scores.pkl
# read path: CASP13_BB_CB/T1015s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1015s1/scores.pkl
# read path: CASP13_AF_FULL/T1009/scores.pkl
# read path: CASP13_ATTNPACK/T1009/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1009/scores.pkl
# read path: CASP13_BB/T1009/scores.pkl
# read path: CASP13_BB_PSF/T1009/scores.pkl
# read path: CASP13_CB_DUMMY/T1009/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1009/scores.pkl
# read path: CASP13_FASPR/T1009/scores.pkl
# read path: CASP13_FASPR_AF/T1009/scores.pkl
# read path: CASP13_PSF_AF/T1009/scores.pkl
# read path: CASP13_BB_CB/T1009/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1009/scores.pkl
# read path: CASP13_AF_FULL/T0985/scores.pkl
# read path: CASP13_ATTNPACK/T0985/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0985/scores.pkl
# read path: CASP13_BB/T0985/scores.pkl
# read path: CASP13_BB_PSF/T0985/scores.pkl
# read path: CASP13_CB_DUMMY/T0985/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0985/scores.pkl
# read path: CASP13_FASPR/T0985/scores.pkl
# read path: CASP13_FASPR_AF/T0985/scores.pkl
# read path: CASP13_PSF_AF/T0985/scores.pkl
# read path: CASP13_BB_CB/T0985/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0985/scores.pkl
# read path: CASP13_AF_FULL/T0951/scores.pkl
# read path: CASP13_ATTNPACK/T0951/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0951/scores.pkl
# read path: CASP13_BB/T0951/scores.pkl
# read path: CASP13_BB_PSF/T0951/scores.pkl
# read path: CASP13_CB_DUMMY/T0951/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0951/scores.pkl
# read path: CASP13_FASPR/T0951/scores.pkl
# read path: CASP13_FASPR_AF/T0951/scores.pkl
# read path: CASP13_PSF_AF/T0951/scores.pkl
# read path: CASP13_BB_CB/T0951/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0951/scores.pkl
# read path: CASP13_AF_FULL/T0987/scores.pkl
# read path: CASP13_ATTNPACK/T0987/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0987/scores.pkl
# read path: CASP13_BB/T0987/scores.pkl
# read path: CASP13_BB_PSF/T0987/scores.pkl
# read path: CASP13_CB_DUMMY/T0987/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0987/scores.pkl
# read path: CASP13_FASPR/T0987/scores.pkl
# read path: CASP13_FASPR_AF/T0987/scores.pkl
# read path: CASP13_PSF_AF/T0987/scores.pkl
# read path: CASP13_BB_CB/T0987/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0987/scores.pkl
# read path: CASP13_AF_FULL/T0993s1/scores.pkl
# read path: CASP13_ATTNPACK/T0993s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0993s1/scores.pkl
# read path: CASP13_BB/T0993s1/scores.pkl
# read path: CASP13_BB_PSF/T0993s1/scores.pkl
# read path: CASP13_CB_DUMMY/T0993s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0993s1/scores.pkl
# read path: CASP13_FASPR/T0993s1/scores.pkl
# read path: CASP13_FASPR_AF/T0993s1/scores.pkl
# read path: CASP13_PSF_AF/T0993s1/scores.pkl
# read path: CASP13_BB_CB/T0993s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0993s1/scores.pkl
# read path: CASP13_AF_FULL/T0986s1/scores.pkl
# read path: CASP13_ATTNPACK/T0986s1/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0986s1/scores.pkl
# read path: CASP13_BB/T0986s1/scores.pkl
# read path: CASP13_BB_PSF/T0986s1/scores.pkl
# read path: CASP13_CB_DUMMY/T0986s1/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0986s1/scores.pkl
# read path: CASP13_FASPR/T0986s1/scores.pkl
# read path: CASP13_FASPR_AF/T0986s1/scores.pkl
# read path: CASP13_PSF_AF/T0986s1/scores.pkl
# read path: CASP13_BB_CB/T0986s1/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0986s1/scores.pkl
# read path: CASP13_AF_FULL/T0988/scores.pkl
# read path: CASP13_ATTNPACK/T0988/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0988/scores.pkl
# read path: CASP13_BB/T0988/scores.pkl
# read path: CASP13_BB_PSF/T0988/scores.pkl
# read path: CASP13_CB_DUMMY/T0988/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0988/scores.pkl
# read path: CASP13_FASPR/T0988/scores.pkl
# read path: CASP13_FASPR_AF/T0988/scores.pkl
# read path: CASP13_PSF_AF/T0988/scores.pkl
# read path: CASP13_BB_CB/T0988/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0988/scores.pkl
# read path: CASP13_AF_FULL/T0981/scores.pkl
# read path: CASP13_ATTNPACK/T0981/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0981/scores.pkl
# read path: CASP13_BB/T0981/scores.pkl
# read path: CASP13_BB_PSF/T0981/scores.pkl
# read path: CASP13_CB_DUMMY/T0981/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0981/scores.pkl
# read path: CASP13_FASPR/T0981/scores.pkl
# read path: CASP13_FASPR_AF/T0981/scores.pkl
# read path: CASP13_PSF_AF/T0981/scores.pkl
# read path: CASP13_BB_CB/T0981/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0981/scores.pkl
# read path: CASP13_AF_FULL/T1021s2/scores.pkl
# read path: CASP13_ATTNPACK/T1021s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1021s2/scores.pkl
# read path: CASP13_BB/T1021s2/scores.pkl
# read path: CASP13_BB_PSF/T1021s2/scores.pkl
# read path: CASP13_CB_DUMMY/T1021s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1021s2/scores.pkl
# read path: CASP13_FASPR/T1021s2/scores.pkl
# read path: CASP13_FASPR_AF/T1021s2/scores.pkl
# read path: CASP13_PSF_AF/T1021s2/scores.pkl
# read path: CASP13_BB_CB/T1021s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1021s2/scores.pkl
# read path: CASP13_AF_FULL/T0953s2/scores.pkl
# read path: CASP13_ATTNPACK/T0953s2/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0953s2/scores.pkl
# read path: CASP13_BB/T0953s2/scores.pkl
# read path: CASP13_BB_PSF/T0953s2/scores.pkl
# read path: CASP13_CB_DUMMY/T0953s2/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0953s2/scores.pkl
# read path: CASP13_FASPR/T0953s2/scores.pkl
# read path: CASP13_FASPR_AF/T0953s2/scores.pkl
# read path: CASP13_PSF_AF/T0953s2/scores.pkl
# read path: CASP13_BB_CB/T0953s2/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0953s2/scores.pkl
# read path: CASP13_AF_FULL/T0967/scores.pkl
# read path: CASP13_ATTNPACK/T0967/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0967/scores.pkl
# read path: CASP13_BB/T0967/scores.pkl
# read path: CASP13_BB_PSF/T0967/scores.pkl
# read path: CASP13_CB_DUMMY/T0967/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0967/scores.pkl
# read path: CASP13_FASPR/T0967/scores.pkl
# read path: CASP13_FASPR_AF/T0967/scores.pkl
# read path: CASP13_PSF_AF/T0967/scores.pkl
# read path: CASP13_BB_CB/T0967/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0967/scores.pkl
# read path: CASP13_AF_FULL/T0962/scores.pkl
# read path: CASP13_ATTNPACK/T0962/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0962/scores.pkl
# read path: CASP13_BB/T0962/scores.pkl
# read path: CASP13_BB_PSF/T0962/scores.pkl
# read path: CASP13_CB_DUMMY/T0962/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0962/scores.pkl
# read path: CASP13_FASPR/T0962/scores.pkl
# read path: CASP13_FASPR_AF/T0962/scores.pkl
# read path: CASP13_PSF_AF/T0962/scores.pkl
# read path: CASP13_BB_CB/T0962/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0962/scores.pkl
# read path: CASP13_AF_FULL/T0960/scores.pkl
# read path: CASP13_ATTNPACK/T0960/scores.pkl
# read path: CASP13_ATTNPACK_AF/T0960/scores.pkl
# read path: CASP13_BB/T0960/scores.pkl
# read path: CASP13_BB_PSF/T0960/scores.pkl
# read path: CASP13_CB_DUMMY/T0960/scores.pkl
# read path: CASP13_CB_HEURISTIC/T0960/scores.pkl
# read path: CASP13_FASPR/T0960/scores.pkl
# read path: CASP13_FASPR_AF/T0960/scores.pkl
# read path: CASP13_PSF_AF/T0960/scores.pkl
# read path: CASP13_BB_CB/T0960/scores.pkl
# read path: CASP13_TEMPLATE_AF/T0960/scores.pkl
# read path: CASP13_AF_FULL/T1003/scores.pkl
# read path: CASP13_ATTNPACK/T1003/scores.pkl
# read path: CASP13_ATTNPACK_AF/T1003/scores.pkl
# read path: CASP13_BB/T1003/scores.pkl
# read path: CASP13_BB_PSF/T1003/scores.pkl
# read path: CASP13_CB_DUMMY/T1003/scores.pkl
# read path: CASP13_CB_HEURISTIC/T1003/scores.pkl
# read path: CASP13_FASPR/T1003/scores.pkl
# read path: CASP13_FASPR_AF/T1003/scores.pkl
# read path: CASP13_PSF_AF/T1003/scores.pkl
# read path: CASP13_BB_CB/T1003/scores.pkl
# read path: CASP13_TEMPLATE_AF/T1003/scores.pkl
# read path: CASP14_AF_FULL/T1079/scores.pkl
# read path: CASP14_ATTNPACK/T1079/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1079/scores.pkl
# read path: CASP14_BB/T1079/scores.pkl
# read path: CASP14_BB_PSF/T1079/scores.pkl
# read path: CASP14_CB_DUMMY/T1079/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1079/scores.pkl
# read path: CASP14_FASPR/T1079/scores.pkl
# read path: CASP14_FASPR_AF/T1079/scores.pkl
# read path: CASP14_PSF_AF/T1079/scores.pkl
# read path: CASP14_BB_CB/T1079/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1079/scores.pkl
# read path: CASP14_AF_FULL/T1032/scores.pkl
# read path: CASP14_ATTNPACK/T1032/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1032/scores.pkl
# read path: CASP14_BB/T1032/scores.pkl
# read path: CASP14_BB_PSF/T1032/scores.pkl
# read path: CASP14_CB_DUMMY/T1032/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1032/scores.pkl
# read path: CASP14_FASPR/T1032/scores.pkl
# read path: CASP14_FASPR_AF/T1032/scores.pkl
# read path: CASP14_PSF_AF/T1032/scores.pkl
# read path: CASP14_BB_CB/T1032/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1032/scores.pkl
# read path: CASP14_AF_FULL/T1034/scores.pkl
# read path: CASP14_ATTNPACK/T1034/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1034/scores.pkl
# read path: CASP14_BB/T1034/scores.pkl
# read path: CASP14_BB_PSF/T1034/scores.pkl
# read path: CASP14_CB_DUMMY/T1034/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1034/scores.pkl
# read path: CASP14_FASPR/T1034/scores.pkl
# read path: CASP14_FASPR_AF/T1034/scores.pkl
# read path: CASP14_PSF_AF/T1034/scores.pkl
# read path: CASP14_BB_CB/T1034/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1034/scores.pkl
# read path: CASP14_AF_FULL/T1045s2/scores.pkl
# read path: CASP14_ATTNPACK/T1045s2/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1045s2/scores.pkl
# read path: CASP14_BB/T1045s2/scores.pkl
# read path: CASP14_BB_PSF/T1045s2/scores.pkl
# read path: CASP14_CB_DUMMY/T1045s2/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1045s2/scores.pkl
# read path: CASP14_FASPR/T1045s2/scores.pkl
# read path: CASP14_FASPR_AF/T1045s2/scores.pkl
# read path: CASP14_PSF_AF/T1045s2/scores.pkl
# read path: CASP14_BB_CB/T1045s2/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1045s2/scores.pkl
# read path: CASP14_AF_FULL/T1095/scores.pkl
# read path: CASP14_ATTNPACK/T1095/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1095/scores.pkl
# read path: CASP14_BB/T1095/scores.pkl
# read path: CASP14_BB_PSF/T1095/scores.pkl
# read path: CASP14_CB_DUMMY/T1095/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1095/scores.pkl
# read path: CASP14_FASPR/T1095/scores.pkl
# read path: CASP14_FASPR_AF/T1095/scores.pkl
# read path: CASP14_PSF_AF/T1095/scores.pkl
# read path: CASP14_BB_CB/T1095/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1095/scores.pkl
# read path: CASP14_AF_FULL/T1070/scores.pkl
# read path: CASP14_ATTNPACK/T1070/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1070/scores.pkl
# read path: CASP14_BB/T1070/scores.pkl
# read path: CASP14_BB_PSF/T1070/scores.pkl
# read path: CASP14_CB_DUMMY/T1070/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1070/scores.pkl
# read path: CASP14_FASPR/T1070/scores.pkl
# read path: CASP14_FASPR_AF/T1070/scores.pkl
# read path: CASP14_PSF_AF/T1070/scores.pkl
# read path: CASP14_BB_CB/T1070/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1070/scores.pkl
# read path: CASP14_AF_FULL/T1087/scores.pkl
# read path: CASP14_ATTNPACK/T1087/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1087/scores.pkl
# read path: CASP14_BB/T1087/scores.pkl
# read path: CASP14_BB_PSF/T1087/scores.pkl
# read path: CASP14_CB_DUMMY/T1087/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1087/scores.pkl
# read path: CASP14_FASPR/T1087/scores.pkl
# read path: CASP14_FASPR_AF/T1087/scores.pkl
# read path: CASP14_PSF_AF/T1087/scores.pkl
# read path: CASP14_BB_CB/T1087/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1087/scores.pkl
# read path: CASP14_AF_FULL/T1037/scores.pkl
# read path: CASP14_ATTNPACK/T1037/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1037/scores.pkl
# read path: CASP14_BB/T1037/scores.pkl
# read path: CASP14_BB_PSF/T1037/scores.pkl
# read path: CASP14_CB_DUMMY/T1037/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1037/scores.pkl
# read path: CASP14_FASPR/T1037/scores.pkl
# read path: CASP14_FASPR_AF/T1037/scores.pkl
# read path: CASP14_PSF_AF/T1037/scores.pkl
# read path: CASP14_BB_CB/T1037/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1037/scores.pkl
# read path: CASP14_AF_FULL/T1100/scores.pkl
# read path: CASP14_ATTNPACK/T1100/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1100/scores.pkl
# read path: CASP14_BB/T1100/scores.pkl
# read path: CASP14_BB_PSF/T1100/scores.pkl
# read path: CASP14_CB_DUMMY/T1100/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1100/scores.pkl
# read path: CASP14_FASPR/T1100/scores.pkl
# read path: CASP14_FASPR_AF/T1100/scores.pkl
# read path: CASP14_PSF_AF/T1100/scores.pkl
# read path: CASP14_BB_CB/T1100/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1100/scores.pkl
# read path: CASP14_AF_FULL/T1047s2/scores.pkl
# read path: CASP14_ATTNPACK/T1047s2/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1047s2/scores.pkl
# read path: CASP14_BB/T1047s2/scores.pkl
# read path: CASP14_BB_PSF/T1047s2/scores.pkl
# read path: CASP14_CB_DUMMY/T1047s2/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1047s2/scores.pkl
# read path: CASP14_FASPR/T1047s2/scores.pkl
# read path: CASP14_FASPR_AF/T1047s2/scores.pkl
# read path: CASP14_PSF_AF/T1047s2/scores.pkl
# read path: CASP14_BB_CB/T1047s2/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1047s2/scores.pkl
# read path: CASP14_AF_FULL/T1088/scores.pkl
# read path: CASP14_ATTNPACK/T1088/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1088/scores.pkl
# read path: CASP14_BB/T1088/scores.pkl
# read path: CASP14_BB_PSF/T1088/scores.pkl
# read path: CASP14_CB_DUMMY/T1088/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1088/scores.pkl
# read path: CASP14_FASPR/T1088/scores.pkl
# read path: CASP14_FASPR_AF/T1088/scores.pkl
# read path: CASP14_PSF_AF/T1088/scores.pkl
# read path: CASP14_BB_CB/T1088/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1088/scores.pkl
# read path: CASP14_AF_FULL/T1024/scores.pkl
# read path: CASP14_ATTNPACK/T1024/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1024/scores.pkl
# read path: CASP14_BB/T1024/scores.pkl
# read path: CASP14_BB_PSF/T1024/scores.pkl
# read path: CASP14_CB_DUMMY/T1024/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1024/scores.pkl
# read path: CASP14_FASPR/T1024/scores.pkl
# read path: CASP14_FASPR_AF/T1024/scores.pkl
# read path: CASP14_PSF_AF/T1024/scores.pkl
# read path: CASP14_BB_CB/T1024/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1024/scores.pkl
# read path: CASP14_AF_FULL/T1068/scores.pkl
# read path: CASP14_ATTNPACK/T1068/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1068/scores.pkl
# read path: CASP14_BB/T1068/scores.pkl
# read path: CASP14_BB_PSF/T1068/scores.pkl
# read path: CASP14_CB_DUMMY/T1068/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1068/scores.pkl
# read path: CASP14_FASPR/T1068/scores.pkl
# read path: CASP14_FASPR_AF/T1068/scores.pkl
# read path: CASP14_PSF_AF/T1068/scores.pkl
# read path: CASP14_BB_CB/T1068/scores.pkl
# ...
# read path: CASP14_FASPR/T1048/scores.pkl
# read path: CASP14_FASPR_AF/T1048/scores.pkl
# read path: CASP14_PSF_AF/T1048/scores.pkl
# read path: CASP14_BB_CB/T1048/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1048/scores.pkl
# read path: CASP14_AF_FULL/T1039/scores.pkl
# read path: CASP14_ATTNPACK/T1039/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1039/scores.pkl
# read path: CASP14_BB/T1039/scores.pkl
# read path: CASP14_BB_PSF/T1039/scores.pkl
# read path: CASP14_CB_DUMMY/T1039/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1039/scores.pkl
# read path: CASP14_FASPR/T1039/scores.pkl
# read path: CASP14_FASPR_AF/T1039/scores.pkl
# read path: CASP14_PSF_AF/T1039/scores.pkl
# read path: CASP14_BB_CB/T1039/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1039/scores.pkl
# read path: CASP14_AF_FULL/T1099/scores.pkl
# read path: CASP14_ATTNPACK/T1099/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1099/scores.pkl
# read path: CASP14_BB/T1099/scores.pkl
# read path: CASP14_BB_PSF/T1099/scores.pkl
# read path: CASP14_CB_DUMMY/T1099/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1099/scores.pkl
# read path: CASP14_FASPR/T1099/scores.pkl
# read path: CASP14_FASPR_AF/T1099/scores.pkl
# read path: CASP14_PSF_AF/T1099/scores.pkl
# read path: CASP14_BB_CB/T1099/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1099/scores.pkl
# read path: CASP14_AF_FULL/T1027/scores.pkl
# read path: CASP14_ATTNPACK/T1027/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1027/scores.pkl
# read path: CASP14_BB/T1027/scores.pkl
# read path: CASP14_BB_PSF/T1027/scores.pkl
# read path: CASP14_CB_DUMMY/T1027/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1027/scores.pkl
# read path: CASP14_FASPR/T1027/scores.pkl
# read path: CASP14_FASPR_AF/T1027/scores.pkl
# read path: CASP14_PSF_AF/T1027/scores.pkl
# read path: CASP14_BB_CB/T1027/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1027/scores.pkl
# read path: CASP14_AF_FULL/T1046s1/scores.pkl
# read path: CASP14_ATTNPACK/T1046s1/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1046s1/scores.pkl
# read path: CASP14_BB/T1046s1/scores.pkl
# read path: CASP14_BB_PSF/T1046s1/scores.pkl
# read path: CASP14_CB_DUMMY/T1046s1/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1046s1/scores.pkl
# read path: CASP14_FASPR/T1046s1/scores.pkl
# read path: CASP14_FASPR_AF/T1046s1/scores.pkl
# read path: CASP14_PSF_AF/T1046s1/scores.pkl
# read path: CASP14_BB_CB/T1046s1/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1046s1/scores.pkl
# read path: CASP14_AF_FULL/T1089/scores.pkl
# read path: CASP14_ATTNPACK/T1089/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1089/scores.pkl
# read path: CASP14_BB/T1089/scores.pkl
# read path: CASP14_BB_PSF/T1089/scores.pkl
# read path: CASP14_CB_DUMMY/T1089/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1089/scores.pkl
# read path: CASP14_FASPR/T1089/scores.pkl
# read path: CASP14_FASPR_AF/T1089/scores.pkl
# read path: CASP14_PSF_AF/T1089/scores.pkl
# read path: CASP14_BB_CB/T1089/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1089/scores.pkl
# read path: CASP14_AF_FULL/T1049/scores.pkl
# read path: CASP14_ATTNPACK/T1049/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1049/scores.pkl
# read path: CASP14_BB/T1049/scores.pkl
# read path: CASP14_BB_PSF/T1049/scores.pkl
# read path: CASP14_CB_DUMMY/T1049/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1049/scores.pkl
# read path: CASP14_FASPR/T1049/scores.pkl
# read path: CASP14_FASPR_AF/T1049/scores.pkl
# read path: CASP14_PSF_AF/T1049/scores.pkl
# read path: CASP14_BB_CB/T1049/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1049/scores.pkl
# read path: CASP14_AF_FULL/T1031/scores.pkl
# read path: CASP14_ATTNPACK/T1031/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1031/scores.pkl
# read path: CASP14_BB/T1031/scores.pkl
# read path: CASP14_BB_PSF/T1031/scores.pkl
# read path: CASP14_CB_DUMMY/T1031/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1031/scores.pkl
# read path: CASP14_FASPR/T1031/scores.pkl
# read path: CASP14_FASPR_AF/T1031/scores.pkl
# read path: CASP14_PSF_AF/T1031/scores.pkl
# read path: CASP14_BB_CB/T1031/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1031/scores.pkl
# read path: CASP14_AF_FULL/T1035/scores.pkl
# read path: CASP14_ATTNPACK/T1035/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1035/scores.pkl
# read path: CASP14_BB/T1035/scores.pkl
# read path: CASP14_BB_PSF/T1035/scores.pkl
# read path: CASP14_CB_DUMMY/T1035/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1035/scores.pkl
# read path: CASP14_FASPR/T1035/scores.pkl
# read path: CASP14_FASPR_AF/T1035/scores.pkl
# read path: CASP14_PSF_AF/T1035/scores.pkl
# read path: CASP14_BB_CB/T1035/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1035/scores.pkl
# read path: CASP14_AF_FULL/T1025/scores.pkl
# read path: CASP14_ATTNPACK/T1025/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1025/scores.pkl
# read path: CASP14_BB/T1025/scores.pkl
# read path: CASP14_BB_PSF/T1025/scores.pkl
# read path: CASP14_CB_DUMMY/T1025/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1025/scores.pkl
# read path: CASP14_FASPR/T1025/scores.pkl
# read path: CASP14_FASPR_AF/T1025/scores.pkl
# read path: CASP14_PSF_AF/T1025/scores.pkl
# read path: CASP14_BB_CB/T1025/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1025/scores.pkl
# read path: CASP14_AF_FULL/T1084/scores.pkl
# read path: CASP14_ATTNPACK/T1084/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1084/scores.pkl
# read path: CASP14_BB/T1084/scores.pkl
# read path: CASP14_BB_PSF/T1084/scores.pkl
# read path: CASP14_CB_DUMMY/T1084/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1084/scores.pkl
# read path: CASP14_FASPR/T1084/scores.pkl
# read path: CASP14_FASPR_AF/T1084/scores.pkl
# read path: CASP14_PSF_AF/T1084/scores.pkl
# read path: CASP14_BB_CB/T1084/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1084/scores.pkl
# read path: CASP14_AF_FULL/T1045s1/scores.pkl
# read path: CASP14_ATTNPACK/T1045s1/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1045s1/scores.pkl
# read path: CASP14_BB/T1045s1/scores.pkl
# read path: CASP14_BB_PSF/T1045s1/scores.pkl
# read path: CASP14_CB_DUMMY/T1045s1/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1045s1/scores.pkl
# read path: CASP14_FASPR/T1045s1/scores.pkl
# read path: CASP14_FASPR_AF/T1045s1/scores.pkl
# read path: CASP14_PSF_AF/T1045s1/scores.pkl
# read path: CASP14_BB_CB/T1045s1/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1045s1/scores.pkl
# read path: CASP14_AF_FULL/T1047s1/scores.pkl
# read path: CASP14_ATTNPACK/T1047s1/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1047s1/scores.pkl
# read path: CASP14_BB/T1047s1/scores.pkl
# read path: CASP14_BB_PSF/T1047s1/scores.pkl
# read path: CASP14_CB_DUMMY/T1047s1/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1047s1/scores.pkl
# read path: CASP14_FASPR/T1047s1/scores.pkl
# read path: CASP14_FASPR_AF/T1047s1/scores.pkl
# read path: CASP14_PSF_AF/T1047s1/scores.pkl
# read path: CASP14_BB_CB/T1047s1/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1047s1/scores.pkl
# read path: CASP14_AF_FULL/T1058/scores.pkl
# read path: CASP14_ATTNPACK/T1058/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1058/scores.pkl
# read path: CASP14_BB/T1058/scores.pkl
# read path: CASP14_BB_PSF/T1058/scores.pkl
# read path: CASP14_CB_DUMMY/T1058/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1058/scores.pkl
# read path: CASP14_FASPR/T1058/scores.pkl
# read path: CASP14_FASPR_AF/T1058/scores.pkl
# read path: CASP14_PSF_AF/T1058/scores.pkl
# read path: CASP14_BB_CB/T1058/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1058/scores.pkl
# read path: CASP14_AF_FULL/T1028/scores.pkl
# read path: CASP14_ATTNPACK/T1028/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1028/scores.pkl
# read path: CASP14_BB/T1028/scores.pkl
# read path: CASP14_BB_PSF/T1028/scores.pkl
# read path: CASP14_CB_DUMMY/T1028/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1028/scores.pkl
# read path: CASP14_FASPR/T1028/scores.pkl
# read path: CASP14_FASPR_AF/T1028/scores.pkl
# read path: CASP14_PSF_AF/T1028/scores.pkl
# read path: CASP14_BB_CB/T1028/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1028/scores.pkl
# read path: CASP14_AF_FULL/T1042/scores.pkl
# read path: CASP14_ATTNPACK/T1042/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1042/scores.pkl
# read path: CASP14_BB/T1042/scores.pkl
# read path: CASP14_BB_PSF/T1042/scores.pkl
# read path: CASP14_CB_DUMMY/T1042/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1042/scores.pkl
# read path: CASP14_FASPR/T1042/scores.pkl
# read path: CASP14_FASPR_AF/T1042/scores.pkl
# read path: CASP14_PSF_AF/T1042/scores.pkl
# read path: CASP14_BB_CB/T1042/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1042/scores.pkl
# read path: CASP14_AF_FULL/T1091/scores.pkl
# read path: CASP14_ATTNPACK/T1091/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1091/scores.pkl
# read path: CASP14_BB/T1091/scores.pkl
# read path: CASP14_BB_PSF/T1091/scores.pkl
# read path: CASP14_CB_DUMMY/T1091/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1091/scores.pkl
# read path: CASP14_FASPR/T1091/scores.pkl
# read path: CASP14_FASPR_AF/T1091/scores.pkl
# read path: CASP14_PSF_AF/T1091/scores.pkl
# read path: CASP14_BB_CB/T1091/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1091/scores.pkl
# read path: CASP14_AF_FULL/T1096/scores.pkl
# read path: CASP14_ATTNPACK/T1096/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1096/scores.pkl
# read path: CASP14_BB/T1096/scores.pkl
# read path: CASP14_BB_PSF/T1096/scores.pkl
# read path: CASP14_CB_DUMMY/T1096/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1096/scores.pkl
# read path: CASP14_FASPR/T1096/scores.pkl
# read path: CASP14_FASPR_AF/T1096/scores.pkl
# read path: CASP14_PSF_AF/T1096/scores.pkl
# read path: CASP14_BB_CB/T1096/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1096/scores.pkl
# read path: CASP14_AF_FULL/T1080/scores.pkl
# read path: CASP14_ATTNPACK/T1080/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1080/scores.pkl
# read path: CASP14_BB/T1080/scores.pkl
# read path: CASP14_BB_PSF/T1080/scores.pkl
# read path: CASP14_CB_DUMMY/T1080/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1080/scores.pkl
# read path: CASP14_FASPR/T1080/scores.pkl
# read path: CASP14_FASPR_AF/T1080/scores.pkl
# read path: CASP14_PSF_AF/T1080/scores.pkl
# read path: CASP14_BB_CB/T1080/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1080/scores.pkl
# read path: CASP14_AF_FULL/T1046s2/scores.pkl
# read path: CASP14_ATTNPACK/T1046s2/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1046s2/scores.pkl
# read path: CASP14_BB/T1046s2/scores.pkl
# read path: CASP14_BB_PSF/T1046s2/scores.pkl
# read path: CASP14_CB_DUMMY/T1046s2/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1046s2/scores.pkl
# read path: CASP14_FASPR/T1046s2/scores.pkl
# read path: CASP14_FASPR_AF/T1046s2/scores.pkl
# read path: CASP14_PSF_AF/T1046s2/scores.pkl
# read path: CASP14_BB_CB/T1046s2/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1046s2/scores.pkl
# read path: CASP14_AF_FULL/T1030/scores.pkl
# read path: CASP14_ATTNPACK/T1030/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1030/scores.pkl
# read path: CASP14_BB/T1030/scores.pkl
# read path: CASP14_BB_PSF/T1030/scores.pkl
# read path: CASP14_CB_DUMMY/T1030/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1030/scores.pkl
# read path: CASP14_FASPR/T1030/scores.pkl
# read path: CASP14_FASPR_AF/T1030/scores.pkl
# read path: CASP14_PSF_AF/T1030/scores.pkl
# read path: CASP14_BB_CB/T1030/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1030/scores.pkl
# read path: CASP14_AF_FULL/T1038/scores.pkl
# read path: CASP14_ATTNPACK/T1038/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1038/scores.pkl
# read path: CASP14_BB/T1038/scores.pkl
# read path: CASP14_BB_PSF/T1038/scores.pkl
# read path: CASP14_CB_DUMMY/T1038/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1038/scores.pkl
# read path: CASP14_FASPR/T1038/scores.pkl
# read path: CASP14_FASPR_AF/T1038/scores.pkl
# read path: CASP14_PSF_AF/T1038/scores.pkl
# read path: CASP14_BB_CB/T1038/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1038/scores.pkl
# read path: CASP14_AF_FULL/T1074/scores.pkl
# read path: CASP14_ATTNPACK/T1074/scores.pkl
# read path: CASP14_ATTNPACK_AF/T1074/scores.pkl
# read path: CASP14_BB/T1074/scores.pkl
# read path: CASP14_BB_PSF/T1074/scores.pkl
# read path: CASP14_CB_DUMMY/T1074/scores.pkl
# read path: CASP14_CB_HEURISTIC/T1074/scores.pkl
# read path: CASP14_FASPR/T1074/scores.pkl
# read path: CASP14_FASPR_AF/T1074/scores.pkl
# read path: CASP14_PSF_AF/T1074/scores.pkl
# read path: CASP14_BB_CB/T1074/scores.pkl
# read path: CASP14_TEMPLATE_AF/T1074/scores.pkl
#            method dataset template            rmsd    rmsd_central  \
# 0         AF_FULL  CASP13    T0969  tensor(0.6657)  tensor(0.3897)
# 1        ATTNPACK  CASP13    T0969  tensor(0.4175)  tensor(0.2984)
# 2     ATTNPACK_AF  CASP13    T0969  tensor(0.4929)  tensor(0.3282)
# 3              BB  CASP13    T0969  tensor(1.3984)  tensor(1.4777)
# 4          BB_PSF  CASP13    T0969  tensor(2.0043)  tensor(1.9445)
# ...           ...     ...      ...             ...             ...
# 1675        FASPR  CASP14    T1074  tensor(0.8142)  tensor(0.3181)
# 1676     FASPR_AF  CASP14    T1074  tensor(0.6993)  tensor(0.2640)
# 1677       PSF_AF  CASP14    T1074  tensor(0.6712)  tensor(0.3035)
# 1678        BB_CB  CASP14    T1074  tensor(0.6505)  tensor(0.3196)
# 1679  TEMPLATE_AF  CASP14    T1074  tensor(0.4848)  tensor(0.2296)
#
#         rmsd_surface      lddt   ost_rmsd  tm_score  af_pLDDT_mean  ...  \
# 0     tensor(0.9379)  0.886784   0.853674  0.985882      93.909463  ...
# 1     tensor(0.5486)  0.968448   0.000002  1.000000      95.010593  ...
# 2     tensor(0.6644)  0.961140   0.192980  0.999206      97.963475  ...
# 3     tensor(1.4392)  0.237550  24.411104  0.332556      38.191893  ...
# 4     tensor(2.0564)  0.763779   0.000002  1.000000       0.000000  ...
# ...              ...       ...        ...       ...            ...  ...
# 1675  tensor(1.1649)  0.938927   0.000004  1.000000       0.000000  ...
# 1676  tensor(0.9546)  0.946269   0.216682  0.997434      97.090909  ...
# 1677  tensor(0.9011)  0.931002   0.278491  0.995786      95.765076  ...
# 1678  tensor(0.8697)  0.939997   0.327176  0.994194      95.671742  ...
# 1679  tensor(0.6349)  0.965110   0.216031  0.997450      97.121970  ...
#
#       att_mae4_mean  att_mae4_x_sasa  local_lddt_mean  local_lddt_x_sasa  \
# 0          0.887363         0.286470         0.877605          -0.436322
# 1          0.894411         0.265607         0.968401          -0.296555
# 2          0.915560         0.278944         0.960630          -0.339867
# 3          1.009008         0.169773         0.265949           0.315805
# 4          0.990235         0.164720         0.779562           0.011087
# ...             ...              ...              ...                ...
# 1675       0.783912        -0.045815         0.939227          -0.347168
# 1676       0.706843         0.127402         0.946242          -0.362431
# 1677       0.739164         0.077023         0.919167          -0.109286
# 1678       0.733337         0.055254         0.939159          -0.372841
# 1679       0.664668         0.128197         0.965038          -0.331532
#
#       att_rmsd_x_pLDDT  att_mae1_x_pLDDT  att_mae2_x_pLDDT  att_mae3_x_pLDDT  \
# 0            -0.199049         -0.187987         -0.274420         -0.122675
# 1            -0.571902         -0.440258         -0.465977         -0.451794
# 2            -0.186836         -0.183652         -0.370422         -0.086370
# 3            -0.122554         -0.143383         -0.067477         -0.115703
# 4                  NaN               NaN               NaN               NaN
# ...                ...               ...               ...               ...
# 1675               NaN               NaN               NaN               NaN
# 1676         -0.011899         -0.107461         -0.055561          0.184164
# 1677         -0.163224         -0.369399         -0.166940          0.260924
# 1678         -0.039311         -0.099025         -0.233232          0.197451
# 1679          0.068303         -0.055139         -0.117046          0.132655
#
#       att_mae4_x_pLDDT  local_lddt_x_pLDDT
# 0            -0.411580            0.597607
# 1            -0.399883            0.529830
# 2            -0.317111            0.255126
# 3             0.034226            0.749233
# 4                  NaN                 NaN
# ...                ...                 ...
# 1675               NaN                 NaN
# 1676          0.164342            0.166558
# 1677          0.300018            0.225778
# 1678          0.402487            0.267431
# 1679          0.348791            0.132768
#
# [1680 rows x 29 columns]

# %% [markdown]
# ## Table variables

# %%
# Might need to be adapted for correct names
method_dict = {
    "BB_CB": "Template C-$\\beta$",
    "AF_FULL": "MSA",
    "ATTNPACK": "AttnPacker",
    "ATTNPACK_AF": "AttnPacker (AF)",
    "BB": "Backbone",
    "BB_PSF": "C36",
    "CB_DUMMY": "Dummy",
    "CB_HEURISTIC": "Heuristic C-$\\beta$",
    "FASPR": "FASPR",
    "FASPR_AF": "FASPR (AF)",
    "PSF_AF": "C36 (AF)",
    "TEMPLATE_AF": "Template",
}
columns = [
    "TM-score $\\uparrow$",
    "lDDT $\\uparrow$",
    "RMSD (\\AA) $\\downarrow$",
    "MAE 1 (rad) $\\downarrow$",
    "MAE 2 (rad) $\\downarrow$",
    "MAE 3 (rad) $\\downarrow$",
    "MAE 4 (rad) $\\downarrow$",
]
measure_dict = {
    "lddt": "lDDT $\\uparrow$",
    "tm_score": "TM-score $\\uparrow$",
    "af_pLDDT_mean": "pLDDT $\\uparrow$",
    "att_rmsd_mean": "RMSD (\\AA) $\\downarrow$",
    "att_mae1_mean": "MAE 1 (rad) $\\downarrow$",
    "att_mae2_mean": "MAE 2 (rad) $\\downarrow$",
    "att_mae3_mean": "MAE 3 (rad) $\\downarrow$",
    "att_mae4_mean": "MAE 4 (rad) $\\downarrow$",
    "method": "Method",
    "dataset": "Dataset",
}

# %% [markdown]
# ## Check if all setups are here

# %%
df["method"] = df["method"].replace(method_dict)
df.groupby(["method", "dataset"])["template"].agg("count")
# Out:
# method               dataset
# AttnPacker           CASP13     78
#                      CASP14     62
# AttnPacker (AF)      CASP13     78
#                      CASP14     62
# Backbone             CASP13     78
#                      CASP14     62
# C36                  CASP13     78
#                      CASP14     62
# C36 (AF)             CASP13     78
#                      CASP14     62
# Dummy                CASP13     78
#                      CASP14     62
# FASPR                CASP13     78
#                      CASP14     62
# FASPR (AF)           CASP13     78
#                      CASP14     62
# Heuristic C-$\beta$  CASP13     78
#                      CASP14     62
# MSA                  CASP13     78
#                      CASP14     62
# Template             CASP13     78
#                      CASP14     62
# Template C-$\beta$   CASP13     78
#                      CASP14     62
# Name: template, dtype: int64

# %% [markdown]
# ## Marshall table

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
grouped = (
    df.rename(measure_dict, axis=1)
    .replace("Method", method_dict)
    .groupby(["Method", "Dataset"])[columns]
    .agg(lambda x: x.abs().mean())
)
grouped_std = (
    df.rename(measure_dict, axis=1)
    .replace("Method", method_dict)
    .groupby(["Method", "Dataset"])[columns]
    .agg(lambda x: x.abs().std())
)
for column in columns:
    grouped_std[f"{column}"] = (
        grouped[column].apply(lambda x: f"{x:.3f}")
        + " $\\pm$ "
        + grouped_std[column].apply(lambda x: f"{x:.3f}")
    )
grouped_std
# Out:
#                             TM-score $\uparrow$    lDDT $\uparrow$  \
# Method              Dataset
# AttnPacker          CASP13    1.000 $\pm$ 0.000  0.953 $\pm$ 0.025
#                     CASP14    1.000 $\pm$ 0.000  0.937 $\pm$ 0.026
# AttnPacker (AF)     CASP13    0.986 $\pm$ 0.031  0.933 $\pm$ 0.038
#                     CASP14    0.983 $\pm$ 0.030  0.910 $\pm$ 0.045
# Backbone            CASP13    0.412 $\pm$ 0.204  0.393 $\pm$ 0.166
#                     CASP14    0.409 $\pm$ 0.200  0.392 $\pm$ 0.178
# C36                 CASP13    1.000 $\pm$ 0.000  0.782 $\pm$ 0.017
#                     CASP14    1.000 $\pm$ 0.000  0.565 $\pm$ 0.076
# C36 (AF)            CASP13    0.962 $\pm$ 0.111  0.890 $\pm$ 0.099
#                     CASP14    0.978 $\pm$ 0.036  0.873 $\pm$ 0.057
# Dummy               CASP13    0.323 $\pm$ 0.200  0.304 $\pm$ 0.174
#                     CASP14    0.318 $\pm$ 0.210  0.311 $\pm$ 0.189
# FASPR               CASP13    1.000 $\pm$ 0.000  0.926 $\pm$ 0.027
#                     CASP14    1.000 $\pm$ 0.000  0.911 $\pm$ 0.030
# FASPR (AF)          CASP13    0.975 $\pm$ 0.088  0.918 $\pm$ 0.069
#                     CASP14    0.983 $\pm$ 0.030  0.905 $\pm$ 0.043
# Heuristic C-$\beta$ CASP13    0.970 $\pm$ 0.093  0.895 $\pm$ 0.070
#                     CASP14    0.979 $\pm$ 0.033  0.883 $\pm$ 0.045
# MSA                 CASP13    0.833 $\pm$ 0.195  0.812 $\pm$ 0.113
#                     CASP14    0.793 $\pm$ 0.178  0.743 $\pm$ 0.146
# Template            CASP13    0.985 $\pm$ 0.032  0.945 $\pm$ 0.038
#                     CASP14    0.982 $\pm$ 0.031  0.926 $\pm$ 0.045
# Template C-$\beta$  CASP13    0.974 $\pm$ 0.062  0.905 $\pm$ 0.040
#                     CASP14    0.971 $\pm$ 0.038  0.883 $\pm$ 0.052
#
#                             RMSD (\AA) $\downarrow$ MAE 1 (rad) $\downarrow$  \
# Method              Dataset
# AttnPacker          CASP13        0.531 $\pm$ 0.201        0.301 $\pm$ 0.149
#                     CASP14        0.687 $\pm$ 0.220        0.414 $\pm$ 0.176
# AttnPacker (AF)     CASP13        0.614 $\pm$ 0.220        0.355 $\pm$ 0.175
#                     CASP14        0.772 $\pm$ 0.263        0.461 $\pm$ 0.203
# Backbone            CASP13        1.107 $\pm$ 0.170        0.739 $\pm$ 0.139
#                     CASP14        1.183 $\pm$ 0.198        0.784 $\pm$ 0.143
# C36                 CASP13        1.731 $\pm$ 0.149        1.339 $\pm$ 0.086
#                     CASP14        1.769 $\pm$ 0.154        1.315 $\pm$ 0.096
# C36 (AF)            CASP13        0.778 $\pm$ 0.215        0.485 $\pm$ 0.177
#                     CASP14        0.883 $\pm$ 0.251        0.551 $\pm$ 0.190
# Dummy               CASP13        1.164 $\pm$ 0.167        0.785 $\pm$ 0.141
#                     CASP14        1.238 $\pm$ 0.184        0.828 $\pm$ 0.137
# FASPR               CASP13        0.756 $\pm$ 0.228        0.451 $\pm$ 0.167
#                     CASP14        0.896 $\pm$ 0.265        0.548 $\pm$ 0.197
# FASPR (AF)          CASP13        0.697 $\pm$ 0.234        0.420 $\pm$ 0.177
#                     CASP14        0.834 $\pm$ 0.274        0.511 $\pm$ 0.206
# Heuristic C-$\beta$ CASP13        0.785 $\pm$ 0.209        0.489 $\pm$ 0.173
#                     CASP14        0.910 $\pm$ 0.247        0.572 $\pm$ 0.190
# MSA                 CASP13        0.797 $\pm$ 0.224        0.516 $\pm$ 0.187
#                     CASP14        0.973 $\pm$ 0.254        0.632 $\pm$ 0.191
# Template            CASP13        0.498 $\pm$ 0.200        0.273 $\pm$ 0.149
#                     CASP14        0.616 $\pm$ 0.235        0.350 $\pm$ 0.185
# Template C-$\beta$  CASP13        0.735 $\pm$ 0.218        0.460 $\pm$ 0.176
#                     CASP14        0.860 $\pm$ 0.265        0.544 $\pm$ 0.196
#
#                             MAE 2 (rad) $\downarrow$ MAE 3 (rad) $\downarrow$  \
# Method              Dataset
# AttnPacker          CASP13         0.393 $\pm$ 0.126        0.775 $\pm$ 0.188
#                     CASP14         0.480 $\pm$ 0.151        0.832 $\pm$ 0.159
# AttnPacker (AF)     CASP13         0.405 $\pm$ 0.131        0.733 $\pm$ 0.184
#                     CASP14         0.484 $\pm$ 0.163        0.790 $\pm$ 0.164
# Backbone            CASP13         0.629 $\pm$ 0.105        0.910 $\pm$ 0.143
#                     CASP14         0.653 $\pm$ 0.107        0.932 $\pm$ 0.152
# C36                 CASP13         0.732 $\pm$ 0.100        0.997 $\pm$ 0.187
#                     CASP14         0.743 $\pm$ 0.121        0.990 $\pm$ 0.168
# C36 (AF)            CASP13         0.475 $\pm$ 0.127        0.817 $\pm$ 0.191
#                     CASP14         0.527 $\pm$ 0.153        0.849 $\pm$ 0.158
# Dummy               CASP13         0.653 $\pm$ 0.102        0.916 $\pm$ 0.165
#                     CASP14         0.673 $\pm$ 0.098        0.950 $\pm$ 0.163
# FASPR               CASP13         0.488 $\pm$ 0.140        0.863 $\pm$ 0.180
#                     CASP14         0.554 $\pm$ 0.168        0.860 $\pm$ 0.156
# FASPR (AF)          CASP13         0.451 $\pm$ 0.140        0.802 $\pm$ 0.194
#                     CASP14         0.514 $\pm$ 0.176        0.820 $\pm$ 0.152
# Heuristic C-$\beta$ CASP13         0.500 $\pm$ 0.123        0.819 $\pm$ 0.158
#                     CASP14         0.557 $\pm$ 0.156        0.870 $\pm$ 0.170
# MSA                 CASP13         0.499 $\pm$ 0.130        0.817 $\pm$ 0.162
#                     CASP14         0.573 $\pm$ 0.149        0.882 $\pm$ 0.158
# Template            CASP13         0.315 $\pm$ 0.128        0.586 $\pm$ 0.180
#                     CASP14         0.381 $\pm$ 0.162        0.649 $\pm$ 0.181
# Template C-$\beta$  CASP13         0.464 $\pm$ 0.129        0.794 $\pm$ 0.169
#                     CASP14         0.516 $\pm$ 0.164        0.842 $\pm$ 0.165
#
#                             MAE 4 (rad) $\downarrow$
# Method              Dataset
# AttnPacker          CASP13         0.951 $\pm$ 0.225
#                     CASP14         0.891 $\pm$ 0.229
# AttnPacker (AF)     CASP13         0.918 $\pm$ 0.226
#                     CASP14         0.862 $\pm$ 0.235
# Backbone            CASP13         0.957 $\pm$ 0.212
#                     CASP14         0.875 $\pm$ 0.234
# C36                 CASP13         0.951 $\pm$ 0.213
#                     CASP14         0.869 $\pm$ 0.240
# C36 (AF)            CASP13         0.948 $\pm$ 0.222
#                     CASP14         0.860 $\pm$ 0.242
# Dummy               CASP13         0.953 $\pm$ 0.221
#                     CASP14         0.876 $\pm$ 0.238
# FASPR               CASP13         1.017 $\pm$ 0.279
#                     CASP14         0.963 $\pm$ 0.246
# FASPR (AF)          CASP13         0.931 $\pm$ 0.238
#                     CASP14         0.888 $\pm$ 0.237
# Heuristic C-$\beta$ CASP13         0.939 $\pm$ 0.230
#                     CASP14         0.869 $\pm$ 0.232
# MSA                 CASP13         0.947 $\pm$ 0.233
#                     CASP14         0.877 $\pm$ 0.229
# Template            CASP13         0.795 $\pm$ 0.229
#                     CASP14         0.756 $\pm$ 0.235
# Template C-$\beta$  CASP13         0.935 $\pm$ 0.221
#                     CASP14         0.854 $\pm$ 0.241

# %% [markdown]
# ## To LaTeX

# %%
selected_rows = [
    "MSA",
    "Dummy",
    "Backbone",
    "Template",
    "Template C-$\\beta$",
    "Heuristic C-$\\beta$",
    "AttnPacker",
    "AttnPacker (AF)",
    "C36",
    "C36 (AF)",
    "FASPR",
    "FASPR (AF)",
]
grouped_std.loc[selected_rows].to_latex(
    float_format="%.3f", escape=False, bold_rows=True
)
# Out:
# '\\begin{tabular}{lllllllll}\n\\toprule\n &  & TM-score $\\uparrow$ & lDDT $\\uparrow$ & RMSD (\\AA) $\\downarrow$ & MAE 1 (rad) $\\downarrow$ & MAE 2 (rad) $\\downarrow$ & MAE 3 (rad) $\\downarrow$ & MAE 4 (rad) $\\downarrow$ \\\\\nMethod & Dataset &  &  &  &  &  &  &  \\\\\n\\midrule\n\\multirow[t]{2}{*}{\\textbf{MSA}} & \\textbf{CASP13} & 0.833 $\\pm$ 0.195 & 0.812 $\\pm$ 0.113 & 0.797 $\\pm$ 0.224 & 0.516 $\\pm$ 0.187 & 0.499 $\\pm$ 0.130 & 0.817 $\\pm$ 0.162 & 0.947 $\\pm$ 0.233 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.793 $\\pm$ 0.178 & 0.743 $\\pm$ 0.146 & 0.973 $\\pm$ 0.254 & 0.632 $\\pm$ 0.191 & 0.573 $\\pm$ 0.149 & 0.882 $\\pm$ 0.158 & 0.877 $\\pm$ 0.229 \\\\\n\\cline{1-9}\n\\multirow[t]{2}{*}{\\textbf{Dummy}} & \\textbf{CASP13} & 0.323 $\\pm$ 0.200 & 0.304 $\\pm$ 0.174 & 1.164 $\\pm$ 0.167 & 0.785 $\\pm$ 0.141 & 0.653 $\\pm$ 0.102 & 0.916 $\\pm$ 0.165 & 0.953 $\\pm$ 0.221 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.318 $\\pm$ 0.210 & 0.311 $\\pm$ 0.189 & 1.238 $\\pm$ 0.184 & 0.828 $\\pm$ 0.137 & 0.673 $\\pm$ 0.098 & 0.950 $\\pm$ 0.163 & 0.876 $\\pm$ 0.238 \\\\\n\\cline{1-9}\n\\multirow[t]{2}{*}{\\textbf{Backbone}} & \\textbf{CASP13} & 0.412 $\\pm$ 0.204 & 0.393 $\\pm$ 0.166 & 1.107 $\\pm$ 0.170 & 0.739 $\\pm$ 0.139 & 0.629 $\\pm$ 0.105 & 0.910 $\\pm$ 0.143 & 0.957 $\\pm$ 0.212 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.409 $\\pm$ 0.200 & 0.392 $\\pm$ 0.178 & 1.183 $\\pm$ 0.198 & 0.784 $\\pm$ 0.143 & 0.653 $\\pm$ 0.107 & 0.932 $\\pm$ 0.152 & 0.875 $\\pm$ 0.234 \\\\\n\\cline{1-9}\n\\multirow[t]{2}{*}{\\textbf{Template}} & \\textbf{CASP13} & 0.985 $\\pm$ 0.032 & 0.945 $\\pm$ 0.038 & 0.498 $\\pm$ 0.200 & 0.273 $\\pm$ 0.149 & 0.315 $\\pm$ 0.128 & 0.586 $\\pm$ 0.180 & 0.795 $\\pm$ 0.229 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.982 $\\pm$ 0.031 & 0.926 $\\pm$ 0.045 & 0.616 $\\pm$ 0.235 & 0.350 $\\pm$ 0.185 & 0.381 $\\pm$ 0.162 & 0.649 $\\pm$ 0.181 & 0.756 $\\pm$ 0.235 \\\\\n\\cline{1-9}\n\\multirow[t]{2}{*}{\\textbf{Template C-$\\beta$}} & \\textbf{CASP13} & 0.974 $\\pm$ 0.062 & 0.905 $\\pm$ 0.040 & 0.735 $\\pm$ 0.218 & 0.460 $\\pm$ 0.176 & 0.464 $\\pm$ 0.129 & 0.794 $\\pm$ 0.169 & 0.935 $\\pm$ 0.221 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.971 $\\pm$ 0.038 & 0.883 $\\pm$ 0.052 & 0.860 $\\pm$ 0.265 & 0.544 $\\pm$ 0.196 & 0.516 $\\pm$ 0.164 & 0.842 $\\pm$ 0.165 & 0.854 $\\pm$ 0.241 \\\\\n\\cline{1-9}\n\\multirow[t]{2}{*}{\\textbf{Heuristic C-$\\beta$}} & \\textbf{CASP13} & 0.970 $\\pm$ 0.093 & 0.895 $\\pm$ 0.070 & 0.785 $\\pm$ 0.209 & 0.489 $\\pm$ 0.173 & 0.500 $\\pm$ 0.123 & 0.819 $\\pm$ 0.158 & 0.939 $\\pm$ 0.230 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.979 $\\pm$ 0.033 & 0.883 $\\pm$ 0.045 & 0.910 $\\pm$ 0.247 & 0.572 $\\pm$ 0.190 & 0.557 $\\pm$ 0.156 & 0.870 $\\pm$ 0.170 & 0.869 $\\pm$ 0.232 \\\\\n\\cline{1-9}\n\\multirow[t]{2}{*}{\\textbf{AttnPacker}} & \\textbf{CASP13} & 1.000 $\\pm$ 0.000 & 0.953 $\\pm$ 0.025 & 0.531 $\\pm$ 0.201 & 0.301 $\\pm$ 0.149 & 0.393 $\\pm$ 0.126 & 0.775 $\\pm$ 0.188 & 0.951 $\\pm$ 0.225 \\\\\n\\textbf{} & \\textbf{CASP14} & 1.000 $\\pm$ 0.000 & 0.937 $\\pm$ 0.026 & 0.687 $\\pm$ 0.220 & 0.414 $\\pm$ 0.176 & 0.480 $\\pm$ 0.151 & 0.832 $\\pm$ 0.159 & 0.891 $\\pm$ 0.229 \\\\\n\\cline{1-9}\n\\multirow[t]{2}{*}{\\textbf{AttnPacker (AF)}} & \\textbf{CASP13} & 0.986 $\\pm$ 0.031 & 0.933 $\\pm$ 0.038 & 0.614 $\\pm$ 0.220 & 0.355 $\\pm$ 0.175 & 0.405 $\\pm$ 0.131 & 0.733 $\\pm$ 0.184 & 0.918 $\\pm$ 0.226 \\\\\n\\textbf{} & \\textbf{CASP14} & 0.983 $\\pm$ 0.030 & 0.910 $\\pm$ 0.045 & 0.772 $\\pm$ 0.263 & 0.461 $\\pm$ 0.203 & 0.484 $\\pm$ 0.163 & 0.790 $\\pm$ 0.164 & 0.862 $\\pm$ 0.235 \\\\\n\\cline{1-9}\n\\multirow[t]{2}{*}{\\textbf{C36}} & \\textbf{CASP13} & 1.000 $\\pm$ 0.000 & 0.782 $\\pm$ 0.017 & 1.731 $\\pm$ 0.149 & 1.339 $\\pm$ 0.086 & 0.732 $\\pm$ 0.100 & 0.997 $\\pm$ 0.187 & 0.951 $\\pm$ 0.213 \\\\\n\\textbf{} & \\textbf{CASP14} & 1.000 $\\pm$ 0.000 & 0.565 $\\pm$ 0.076 & 1.769 $\\pm$ 0.154 & 1.315 $\\pm$ 0.096 & 0.743 $\\pm$ 0.121 & 0.990 $\\pm$ 0.168 & 0.869 $\\pm$ 0.240 \\\\\n\\cline{1-9}\n\\multirow[t ...

# %% [markdown]
# ## Violin plots

# %%
columns = ["TM-score", "lDDT", "RMSD", "MAE 1", "MAE 2", "MAE 3", "MAE 4"]
measure_dict = {
    "lddt": "lDDT",
    "tm_score": "TM-score",
    "af_pLDDT_mean": "pLDDT %",
    "att_rmsd_mean": "RMSD ($\\AA$)",
    "att_mae1_mean": "MAE 1 (rad)",
    "att_mae2_mean": "MAE 2 (rad)",
    "att_mae3_mean": "MAE 3 (rad)",
    "att_mae4_mean": "MAE 4 (rad)",
    "method": "Method",
    "dataset": "Dataset",
}
order = [
    "MSA",
    "Template",
    "Backbone",
    "Heuristic C-$\\beta$",
    "Template C-$\\beta$",
    "AttnPacker",
    "AttnPacker (AF)",
]
metrics = [
    "lDDT",
    "TM-score",
    "pLDDT %",
    "RMSD ($\\AA$)",
    "MAE 1 (rad)",
    "MAE 2 (rad)",
    "MAE 3 (rad)",
    "MAE 4 (rad)",
]

grp = df.rename(measure_dict, axis=1).replace("Method", method_dict)
grp.head()
# Out:
#             Method Dataset template            rmsd    rmsd_central  \
# 0              MSA  CASP13    T0969  tensor(0.6657)  tensor(0.3897)
# 1       AttnPacker  CASP13    T0969  tensor(0.4175)  tensor(0.2984)
# 2  AttnPacker (AF)  CASP13    T0969  tensor(0.4929)  tensor(0.3282)
# 3         Backbone  CASP13    T0969  tensor(1.3984)  tensor(1.4777)
# 4              C36  CASP13    T0969  tensor(2.0043)  tensor(1.9445)
#
#      rmsd_surface      lDDT   ost_rmsd  TM-score    pLDDT %  af_pLDDT_x_sasa  \
# 0  tensor(0.9379)  0.886784   0.853674  0.985882  93.909463        -0.487551
# 1  tensor(0.5486)  0.968448   0.000002  1.000000  95.010593        -0.475299
# 2  tensor(0.6644)  0.961140   0.192980  0.999206  97.963475        -0.505655
# 3  tensor(1.4392)  0.237550  24.411104  0.332556  38.191893         0.042222
# 4  tensor(2.0564)  0.763779   0.000002  1.000000   0.000000              NaN
#
#    RMSD ($\AA$)  att_rmsd_x_sasa  MAE 1 (rad)  att_mae1_x_sasa  MAE 2 (rad)  \
# 0      0.639371         0.326691     0.311609         0.257903     0.357786
# 1      0.401017         0.305336     0.162483         0.219658     0.273718
# 2      0.473445         0.311217     0.192329         0.206278     0.277481
# 3      1.343055         0.041098     0.794124        -0.010325     0.602724
# 4      1.925064         0.056614     1.304803         0.070383     0.815523
#
#    att_mae2_x_sasa  MAE 3 (rad)  att_mae3_x_sasa  MAE 4 (rad)  \
# 0         0.306153     0.706499         0.072877     0.887363
# 1         0.357659     0.643237         0.219879     0.894411
# 2         0.357889     0.515649         0.220336     0.915560
# 3         0.158952     0.923342        -0.053530     1.009008
# 4         0.021470     1.107278        -0.163862     0.990235
#
#    att_mae4_x_sasa  local_lddt_mean  local_lddt_x_sasa  att_rmsd_x_pLDDT  \
# 0         0.286470         0.877605          -0.436322         -0.199049
# 1         0.265607         0.968401          -0.296555         -0.571902
# 2         0.278944         0.960630          -0.339867         -0.186836
# 3         0.169773         0.265949           0.315805         -0.122554
# 4         0.164720         0.779562           0.011087               NaN
#
#    att_mae1_x_pLDDT  att_mae2_x_pLDDT  att_mae3_x_pLDDT  att_mae4_x_pLDDT  \
# 0         -0.187987         -0.274420         -0.122675         -0.411580
# 1         -0.440258         -0.465977         -0.451794         -0.399883
# 2         -0.183652         -0.370422         -0.086370         -0.317111
# 3         -0.143383         -0.067477         -0.115703          0.034226
# 4               NaN               NaN               NaN               NaN
#
#    local_lddt_x_pLDDT
# 0            0.597607
# 1            0.529830
# 2            0.255126
# 3            0.749233
# 4                 NaN

# %%
SMALL_SIZE = 30
BIGGER_SIZE = 30
AXES_SIZE = 20
LEGEND_SIZE = 15
plt.rc("font", size=SMALL_SIZE)  # controls default text sizes
plt.rc("axes", titlesize=AXES_SIZE)  # fontsize of the axes title
plt.rc("axes", labelsize=AXES_SIZE)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=AXES_SIZE)  # fontsize of the tick labels
plt.rc("ytick", labelsize=AXES_SIZE)  # fontsize of the tick labels
plt.rc("legend", fontsize=LEGEND_SIZE)  # legend fontsize
plt.rc("figure", titlesize=BIGGER_SIZE)  # fontsize of the figure title
sns.set_style("whitegrid")

for dataset in ["CASP13", "CASP14"]:
    for metric in metrics:
        plt.figure(figsize=(14, 10))
        ax = sns.violinplot(
            grp[(grp["Dataset"] == dataset) & (grp["Method"].isin(order))],
            x="Method",
            hue="Method",
            y=metric,
            linewidth=1,
            palette="tab10",
            order=order,
        )
        plt.setp(ax.collections, alpha=0.5)
        # sns.swarmplot(grp[grp["Dataset"]=="CASP14"],x="Method", color="red", y="lDDT")
        sns.despine(left=True)
        plt.rcParams.update(
            {
                "figure.facecolor": (0.0, 0.0, 0.0, 0.0),
                "axes.facecolor": (0.0, 0.0, 0.0, 0.0),
                "savefig.facecolor": (0.0, 0.0, 0.0, 0.0),
            }
        )
        plt.xticks(rotation=45, ha="right", rotation_mode="anchor")
        plt.savefig(
            f"visualisations/packing_violin_{dataset}_{metric}.svg",
            bbox_inches="tight",
            transparent=True,
        )
        plt.show()
        plt.clf()

# %%
import pandas as pd
from IPython.display import display, HTML
pd.set_option('display.max_rows', 500)

# %%
orphans = pd.read_csv("orphan_data/table_second.csv", usecols=["identifier","tool","msa_mode", "template_id","rmsd","tm_score","lddt","plddt","max_pae", "ptm"])[["identifier","tool","msa_mode", "template_id","rmsd","tm_score","lddt","plddt","max_pae", "ptm"]]
sorted = orphans.sort_values(["identifier", "tool", "msa_mode", "template_id"])

# %%
for identity in sorted.identifier.unique():
    display(HTML(sorted[sorted.identifier==identity].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>identifier</th>
#       <th>tool</th>
#       <th>msa_mode</th>
#       <th>template_id</th>
#       <th>rmsd</th>
#       <th>tm_score</th>
#       <th>lddt</th>
#       <th>plddt</th>
#       <th>max_pae</th>
#       <th>ptm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>36</th>
#       <td>7a8s</td>
#       <td>ColabFold</td>
#       <td>full</td>
#       <td>comb</td>
#       <td>2.235924</td>
#       <td>0.870354</td>
#       <td>0.762113</td>
#       <td>93.378442</td>
#       <td>30.140625</td>
#       <td>0.89</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>7a8s</td>
#       <td>ColabFold</td>
#       <td>full</td>
#       <td>esm</td>
#       <td>2.181755</td>
#       <td>0.870859</td>
#       <td>0.762754</td>
#       <td>91.987990</td>
#       <td>30.125000</td>
#       <td>0.89</td>
#     </tr>
#     <tr>
#       <th>33</th>
# ...

# %%
casp = pd.read_csv("casp_monomer_data/table_second.csv", usecols=["identifier","tool","msa_mode", "template_id","rmsd","tm_score","lddt","plddt","max_pae", "ptm"])[["identifier","tool","msa_mode", "template_id","rmsd","tm_score","lddt","plddt","max_pae", "ptm"]]
sorted = casp.sort_values(["identifier", "tool", "msa_mode", "template_id"])

# %%
for identity in sorted.identifier.unique():
    display(HTML(sorted[sorted.identifier==identity].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>identifier</th>
#       <th>tool</th>
#       <th>msa_mode</th>
#       <th>template_id</th>
#       <th>rmsd</th>
#       <th>tm_score</th>
#       <th>lddt</th>
#       <th>plddt</th>
#       <th>max_pae</th>
#       <th>ptm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>62</th>
#       <td>1041</td>
#       <td>ColabFold</td>
#       <td>full</td>
#       <td>comb</td>
#       <td>1.237457</td>
#       <td>0.953795</td>
#       <td>0.862976</td>
#       <td>88.105470</td>
#       <td>24.828125</td>
#       <td>0.82</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>1041</td>
#       <td>ColabFold</td>
#       <td>full</td>
#       <td>esm</td>
#       <td>1.237457</td>
#       <td>0.953795</td>
#       <td>0.862976</td>
#       <td>88.105470</td>
#       <td>24.828125</td>
#       <td>0.82</td>
#     </tr>
#     <tr>
#       <th>59</th>
# ...
